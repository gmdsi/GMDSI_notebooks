# %% [markdown]
# # Setup the PEST(++) interface around the modified Freyberg model
#
# In this notebook, we will construct a complex model independent (non-intrusive) interface around an existing `MODFLOW6` model using `pyEMU`. We assume that the reader is at least partially familiar with PEST(++) file formats and working philosophy.
#
# The modified Freyberg groundwater flow model has been constructed and is described in a previous notebook from this series. We will construct the entire PEST(++) interface from scratch here. This setup will be built upon in subsequent tutorials.
#
# We will rely heavily on the `pyemu.PstFrom` class. Although here we employ it with a `MODFLOW6` model, `PstFrom` is designed to be general and software independent (mostly). Some features are only available for `MODFLOW` models (e.g. `SpatialReference`).
#
# The `PstFrom` class automates the construction of high-dimensional PEST(++) interfaces with all the bells and whistles. It provides easy-to-use functions to process model input and output files into PEST(++) datasets. It can assist with setting up spatio-temporaly varying parameters (e.g. pilot points). It handles the generation of geostatisical prior covariance matrices and ensembles. It automates writting a "model run" script. It provides tools to add custom pre- and post-processing functions to this script. It makes adding tweaks and fixes to the PEST(++) interface a breeze. All of this from the comfort of your favourite Python IDE.
#
# During this tutorial we are going to construct a PEST dataset. Amongst other things, we will demonstrate:
#  - how to add observations & parameters from model output & input files;
#  - how to add pre- and post-processing functions to the "model run" script;
#  - how to generate geostatistical structures for spatialy and temporally correlated parameters;
#  - how to edit parameter/observation data sections;
#  - how to generate a prior parameter covariance matrix and prior parameter ensemble;
#
#
#
# First, let's get our model files and sort out some admin.

# %% [markdown]
# ### 1. Admin & Organize Folders
# First some admin. Load the dependencies and organize model folders. Let's copy the original model folder into a new working directory, just to ensure we don't mess up the base files.

# %%
import sys
import os
import shutil
import warnings
warnings.filterwarnings("ignore")
warnings.filterwarnings("ignore", category=DeprecationWarning) 
sys.path.append('../../dependencies/')
import pyemu
import flopy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt;

# %%
# folder containing original model files
org_ws = os.path.join('..', '..', 'models', 'freyberg_mf6')

# set a new workspace folder to avoid breaking things by mistake
sim_ws = os.path.join('freyberg_mf6')

# remove existing folder if it already exists
if os.path.exists(sim_ws):
    shutil.rmtree(sim_ws)

# copy the original model folder across
shutil.copytree(org_ws, sim_ws)
# Out:
# 'freyberg_mf6'

# %% [markdown]
# If you inspect the model folder, you will see that all the `MODFLOW6` model files have been written "externally". This is key for working with the `PstFrom` class (or with PEST(++) in general, really). Essentialy, all pertinent model inputs have been written as independent files in either array or list format. This makes it easier for us to programiatically access and re-write the values in these files.
#
# Array files contain a data type (usually floating points). List files will have a few columns that contain index information and then columns of floating point values (they have a tabular format; think `.csv` files or DataFrames). The `PstFrom` class provides methods for processing these file types into a PEST(++) dataset.

# %%
os.listdir(sim_ws)
# Out:
# ['freyberg6.dis',
#  'freyberg6.dis.grb',
#  'freyberg6.dis_botm_layer1.txt',
#  'freyberg6.dis_botm_layer2.txt',
#  'freyberg6.dis_botm_layer3.txt',
#  'freyberg6.dis_delc.txt',
#  'freyberg6.dis_delr.txt',
#  'freyberg6.dis_idomain_layer1.txt',
#  'freyberg6.dis_idomain_layer2.txt',
#  'freyberg6.dis_idomain_layer3.txt',
#  'freyberg6.dis_top.txt',
#  'freyberg6.ghb',
#  'freyberg6.ghb_stress_period_data_1.txt',
#  'freyberg6.ic',
#  'freyberg6.sfr_perioddata_8.txt',
#  'freyberg6.sfr_perioddata_9.txt',
#  'freyberg6.sto',
#  'freyberg6.sto_iconvert_layer1.txt',
#  'freyberg6.sto_iconvert_layer2.txt',
#  'freyberg6.sto_iconvert_layer3.txt',
#  'freyberg6.sto_ss_layer1.txt',
#  'freyberg6.sto_ss_layer2.txt',
#  'freyberg6.sto_ss_layer3.txt',
#  'freyberg6.sto_sy_layer1.txt',
#  'freyberg6.sto_sy_layer2.txt',
#  'freyberg6.sto_sy_layer3.txt',
#  'freyberg6.tdis',
#  'freyberg6.wel',
#  'freyberg6.wel_stress_period_data_1.txt',
#  'freyberg6.wel_stress_period_data_10.txt',
#  'freyberg6.wel_stress_period_data_11.txt',
#  'freyberg6.wel_stress_period_data_12.txt',
#  'freyberg6.wel_stress_period_data_13.txt',
#  'freyberg6.wel_stress_period_data_14.txt',
#  'freyberg6.wel_stress_period_data_15.txt',
#  'freyberg6.wel_stress_period_data_16.txt',
#  'freyberg6.wel_stress_period_data_17.txt',
#  'freyberg6.wel_stress_period_data_18.txt',
#  'freyberg6.wel_stress_period_data_19.txt',
#  'freyberg6.wel_stress_period_data_2.txt',
#  'freyberg6.wel_stress_period_data_20.txt',
#  'freyberg6.wel_stress_period_data_21.txt',
#  'freyberg6.wel_stress_period_data_22.txt',
#  'freyberg6.wel_stress_period_data_23.txt',
#  'freyberg6.wel_stress_period_data_24.txt',
#  'freyberg6.wel_stress_period_data_25.txt',
#  'freyberg6.wel_stress_period_data_3.txt',
#  'freyberg6.wel_stress_period_data_4.txt',
#  'freyberg6.wel_stress_period_data_5.txt',
#  'freyberg6.wel_stress_period_data_6.txt',
#  'freyberg6.wel_stress_period_data_7.txt',
#  'freyberg6.wel_stress_period_data_8.txt',
#  'freyberg6.wel_stress_period_data_9.txt',
#  'freyberg6_freyberg.cbc',
#  'freyberg6_freyberg.hds',
#  'head.obs',
#  'heads.csv',
#  'mfsim.lst',
#  'mfsim.nam',
#  'sfr.csv',
#  'sfr.obs']

# %% [markdown]
# Now we need just a tiny bit of info about the spatial discretization of the model - this is needed to work out separation distances between parameters to build a geostatistical prior covariance matrix later.
#
# Here we will load the flopy sim and model instance just to help us define some quantities later - flopy is ***not required*** to use the `PstFrom` class. ***Neither is MODFLOW***. However, at the time of writting, support for `SpatialReference` to spatially locate parameters is limited to MODLOW models.
#
# Load the simulation. Run it once to make sure it works and to ***make sure that model output files are in the folder***.

# %%
# load simulation
sim = flopy.mf6.MFSimulation.load(sim_ws=sim_ws)
# load flow model
gwf = sim.get_model()

# run the model once to make sure it works
sim.run_simulation()
# Out:
# loading simulation...
#   loading simulation name file...
#   loading tdis package...
#   loading model gwf6...
#     loading package dis...
#     loading package ic...
#     loading package npf...
#     loading package sto...
#     loading package oc...
#     loading package wel...
#     loading package rch...
#     loading package ghb...
#     loading package sfr...
#     loading package obs...
#   loading ims package freyberg6...
# FloPy is using the following executable to run the model: C:\Program Files\MODFLOW\mf6.exe
#                                    MODFLOW 6
#                 U.S. GEOLOGICAL SURVEY MODULAR HYDROLOGIC MODEL
#                             VERSION 6.2.2 07/30/2021
#
#    MODFLOW 6 compiled Jul 31 2021 14:57:11 with IFORT compiler (ver. 20.21.2)
#
# This software has been approved for release by the U.S. Geological
# Survey (USGS). Although the software has been subjected to rigorous
# review, the USGS reserves the right to update the software as needed
# pursuant to further analysis and review. No warranty, expressed or
# implied, is made by the USGS or the U.S. Government as to the
# functionality of the software and related material nor shall the
# fact of release constitute any such warranty. Furthermore, the
# software is released on condition that neither the USGS nor the U.S.
# Government shall be held liable for any damages resulting from its
# authorized or unauthorized use. Also refer to the USGS Water
# Resources Software User Rights Notice for complete use, copyright,
# and distribution information.
#
#
#  Run start date and time (yyyy/mm/dd hh:mm:ss): 2022/02/18 11:08:40
#
#  Writing simulation list file: mfsim.lst
#  Using Simulation name file: mfsim.nam
#
#     Solving:  Stress period:     1    Time step:     1
#     Solving:  Stress period:     2    Time step:     1
#     Solving:  Stress period:     3    Time step:     1
#     Solving:  Stress period:     4    Time step:     1
#     Solving:  Stress period:     5    Time step:     1
#     Solving:  Stress period:     6    Time step:     1
#     Solving:  Stress period:     7    Time step:     1
#     Solving:  Stress period:     8    Time step:     1
#     Solving:  Stress period:     9    Time step:     1
#     Solving:  Stress period:    10    Time step:     1
#     Solving:  Stress period:    11    Time step:     1
#     Solving:  Stress period:    12    Time step:     1
#     Solving:  Stress period:    13    Time step:     1
#     Solving:  Stress period:    14    Time step:     1
#     Solving:  Stress period:    15    Time step:     1
#     Solving:  Stress period:    16    Time step:     1
#     Solving:  Stress period:    17    Time step:     1
#     Solving:  Stress period:    18    Time step:     1
#     Solving:  Stress period:    19    Time step:     1
#     Solving:  Stress period:    20    Time step:     1
#     Solving:  Stress period:    21    Time step:     1
#     Solving:  Stress period:    22    Time step:     1
#     Solving:  Stress period:    23    Time step:     1
#     Solving:  Stress period:    24    Time step:     1
#     Solving:  Stress period:    25    Time step:     1
#
#  Run end date and time (yyyy/mm/dd hh:mm:ss): 2022/02/18 11:08:41
#  Elapsed run time:  0.652 Seconds
#
#
# WARNING REPORT:
#
#   1. NONLINEAR BLOCK VARIABLE 'OUTER_HCLOSE' IN FILE 'freyberg6.ims' WAS
#      DEPRECATED IN VERSION 6.1.1. SETTING OUTER_DVCLOSE TO OUTER_HCLOSE VALUE.
#   2. LINEAR BLOCK VARIABLE 'INNER_HCLOSE' IN FILE 'freyberg6.ims' WAS
#      DEPRECATED IN VERSION 6.1.1. SETTING INNER_DVCLOSE TO INNER_HCLOSE VALUE.
#  Normal termination of simulation.
# (True, [])

# %% [markdown]
# ### 2. Spatial Reference
# Now we can instantiate a `SpatialReference`. This will later be passed to `PstFrom` to assist with spatially locating parameters (e.g. pilot points and/or cell-by-cell parameters).

# %%
sr = pyemu.helpers.SpatialReference.from_namfile(
        os.path.join(sim_ws, "freyberg6.nam"),
        delr=gwf.dis.delr.array, delc=gwf.dis.delc.array)
# Out:
#    could not remove start_datetime

# %% [markdown]
# ### 3. Instantiate PstFrom
#
# Now we can start to construct the PEST(++) interface by instantiating a `PstFrom` class instance. There are a few things that we need to specify up front:
#
#  - the folder in which we currently have model files (e.g. `sim_ws`). PstFrom will copy all the files from this directory into a new "template" folder.
#  - **template folder**: this is a folder in which the PEST dataset will be constructed. This folder/dataset will form the template for subsequent deployment of PEST(++). It is **not** where PEST(++) will be run.
#  - **longnames**: for backwards compatibility with PEST and PEST_HP (i.e. non-PEST++ versions), which have upper limits to parameter/obsveration names (PEST++ does not). Setting this value to False is only recommended if required.
#  - Whether the model is `zero based` or not.
#  - (optional) the **spatial reference**, as previously discussed. This is only requried if using `pyEMU` to define parameter spatial correlation. Alternatively, you can define these yourself or use utilities available in the PEST-suite.

# %%
# specify a template directory (i.e. the PstFrom working folder)
template_ws = os.path.join("freyberg6_template")

# instantiate PstFrom
pf = pyemu.utils.PstFrom(original_d=sim_ws, # where the model is stored
                            new_d=template_ws, # the PEST template folder
                            remove_existing=True, # ensures a clean start
                            longnames=True, # set False if using PEST/PEST_HP
                            spatial_reference=sr, #the spatial reference we generated earlier
                            zero_based=False, # does the MODEL use zero based indices? For example, MODFLOW does NOT
                            start_datetime="1-1-2018") # required when specifying temporal correlation between parameters
# Out:
# 2022-02-18 11:08:41.494265 starting: opening PstFrom.log for logging
# 2022-02-18 11:08:41.495264 starting PstFrom process
# 2022-02-18 11:08:41.495264 starting: setting up dirs
# 2022-02-18 11:08:41.496261 starting: removing existing new_d 'freyberg6_template'
# 2022-02-18 11:08:41.881592 finished: removing existing new_d 'freyberg6_template' took: 0:00:00.385331
# 2022-02-18 11:08:42.890400 starting: copying original_d 'freyberg_mf6' to new_d 'freyberg6_template'
# 2022-02-18 11:08:43.058921 finished: copying original_d 'freyberg_mf6' to new_d 'freyberg6_template' took: 0:00:00.168521
# 2022-02-18 11:08:43.059918 finished: setting up dirs took: 0:00:01.564654

# %% [markdown]
# ### 4. Observations
#
# We now have a `PstFrom` instance assigned to the variable `pf`. For now it is only an empty container to which we can start adding "observations", "parameters" and other bits and bobs.
#
# Lets start with observations because they are easier. `MODFLOW6` makes life even easier by recording observations in nicely organized .csv files. Isn't that a peach!
#
# #### 4.1 Freyberg Recap
# As you may recall from the "*intro to Freyberg*" tutorial, the model is configured to record time series of head at observation wells, and flux at three locations along the river. These are recorded in external .csv files named `heads.csv` and `sfr.csv`, respectively. You should be able to see these files in the model folder.
#
# Recall that each .csv houses records of observation time-series. Outputs are recorded for each simulated stress-period. The model starts with a single steady-state stress-period, followed by 24 monthly transient stress-periods. The steady-state and first 12 transient stress-periods simulate the history-matching period. The last 12 transient stress periods simulate future conditions (i.e. the prediction period).

# %%
# check the output csv file names
for i in gwf.obs:
    print(i.output.obs_names)
# Out:
# ['sfr.csv']
# ['heads.csv']

# %% [markdown]
# Let's start with the 'heads.csv' file. First load it as a DataFrame to take a look.
#
# As you can see, there are many columns, one for each observation site. Conveniently, * *cough* * they are named according to the cell layer, row and column. Note that at every site, there is an observation in both the top and bottom layer (0_ and 2_). We will make use of this later to create "secondary observations" of head differences between layers...but let's not get distracted.
#
# The values in the *.csv* file were generated by running the model. (***IMPORTANT!***) However, `PstFrom` assumes that values in this file are the *target* observation values, and they will be used to populate the PEST(++) dataset. Now, you can change these values later on if you wish. However, it can get a bit messy. So you either need to populate model output files with the target values, or update values in the PEST(++) dataset later on. Which approach you adopt is up to personal preference and/or specifics of your modelling workflow.
#
# We will demonstrate both in this notebook.

# %%
df = pd.read_csv(os.path.join(template_ws,"heads.csv"),index_col=0)
df.head()
# Out:
#        TRGW_2_2_15  TRGW_2_2_9  TRGW_2_3_8  TRGW_2_9_1  TRGW_2_13_10  \
# time
# 1.0      34.339371   34.581652   34.611269   34.872233     34.257587
# 32.0     34.422410   34.680539   34.711674   34.972781     34.381012
# 61.0     34.495957   34.778186   34.811777   35.083356     34.481550
# 92.0     34.541401   34.848355   34.884781   35.177773     34.535931
# 122.0    34.538046   34.859540   34.898037   35.214376     34.519945
#
#        TRGW_2_15_16  TRGW_2_21_10  TRGW_2_22_15  TRGW_2_24_4  TRGW_2_26_6  \
# time
# 1.0       34.136402     34.144486     34.027671    34.310866    34.171622
# 32.0      34.245389     34.272053     34.137782    34.437040    34.313022
# 61.0      34.330166     34.376147     34.218984    34.554584    34.427174
# 92.0      34.372218     34.431584     34.257500    34.631270    34.490398
# 122.0     34.353194     34.414273     34.236604    34.633647    34.475787
#
#        ...  TRGW_0_9_1  TRGW_0_13_10  TRGW_0_15_16  TRGW_0_21_10  \
# time   ...
# 1.0    ...   34.878144     34.263200     34.141615     34.150087
# 32.0   ...   34.978649     34.385899     34.250189     34.276799
# 61.0   ...   35.089255     34.487453     34.335923     34.381917
# 92.0   ...   35.183927     34.542985     34.378908     34.438584
# 122.0  ...   35.220884     34.527784     34.360428     34.422143
#
#        TRGW_0_22_15  TRGW_0_24_4  TRGW_0_26_6  TRGW_0_29_15  TRGW_0_33_7  \
# time
# 1.0       33.992378    34.316580    34.177242     33.909884    33.985754
# 32.0      34.087175    34.441928    34.317371     33.992246    34.102202
# 61.0      34.157801    34.560035    34.432626     34.057961    34.195661
# 92.0      34.191420    34.637737    34.497162     34.090584    34.243705
# 122.0     34.173629    34.641042    34.483587     34.076343    34.225780
#
#        TRGW_0_34_10
# time
# 1.0       33.890225
# 32.0      34.005258
# 61.0      34.086047
# 92.0      34.121032
# 122.0     34.095256
#
# [5 rows x 26 columns]

# %% [markdown]
# #### 4.2 Prepare Observation Files
#
# We will start by populating our "model output" file with measured values. For this synthetic case, we conveniently have observations for all model output times and sites. (These "measured" values were generated using the same model with a randomly generated set of parameters; noise was added to all observations.)
#
# In the next cell we read a .csv that contains measured obsevration values. As it has the exact same structure as our model output file, we can simpy replace the values in the model output file (and re-write it!). In real-world cases this step will likley be a bit more involved.

# %%
# read the measured head values
hds_meas = pd.read_csv(os.path.join('..', '..', 'models', 'freyberg_mf6_truth',"heads.meas.csv"),
                    index_col=0)

# re-write the model output .csv file with the measured values
hds_meas.to_csv(os.path.join(template_ws,"heads.csv"))

# %% [markdown]
# #### 4.2. Adding Observations
#
# Now that our model output file contains the "target values", we can use the `PstFrom.add_observations()` method to add observations to our `pf` object. This method reads ***list-type*** files. The assumption is that these files are organized in a tabular format.
#
# We are going to tell `pf` which columns of this file contain observations. Values in these columns will be assigned to *observation values*.
#
# We can also inform it if there is an index column. Values in this column will be included in the *observation names*.
#
# We could also specify which rows to include as observations. But observations are free...so why not keep them all!
#
# Let's add observations from `heads.csv`. The first column of this file records the time at which the value is simulated. Let's use that as the index column (this becomes useful later on to post-process results). We want all other columns as observation values.

# %%
hds_df = pf.add_observations("heads.csv", # the model output file to read
                            insfile="heads.csv.ins", #optional, the instruction file name
                            index_cols="time", #column header to use as index; can also use column number (zero-based) instead of the header name
                            use_cols=list(df.columns.values), #names of columns that include observation values; can also use column number (zero-based) instead of the header name
                            prefix="hds") #prefix to all observation names; choose something logical and easy o find. We use it later on to select obsevrations
# Out:
# 2022-02-18 11:08:43.145737 starting: adding observations from output file heads.csv
# 2022-02-18 11:08:43.146733 starting: adding observations from tabular output file '['heads.csv']'
# 2022-02-18 11:08:43.146733 starting: reading list-style file: freyberg6_template\heads.csv
# 2022-02-18 11:08:43.156774 finished: reading list-style file: freyberg6_template\heads.csv took: 0:00:00.010041
# 2022-02-18 11:08:43.156774 starting: building insfile for tabular output file heads.csv
# 2022-02-18 11:08:43.168675 finished: building insfile for tabular output file heads.csv took: 0:00:00.011901
# 2022-02-18 11:08:43.168675 starting: adding observation from instruction file 'freyberg6_template\heads.csv.ins'
# 2022-02-18 11:08:43.186661 finished: adding observation from instruction file 'freyberg6_template\heads.csv.ins' took: 0:00:00.017986
# 2022-02-18 11:08:43.188654 finished: adding observations from tabular output file '['heads.csv']' took: 0:00:00.041921

# %% [markdown]
# Let's inspect what we just created.
#
# We can see that the `.add_observations()` method returned a dataframe with lots of useful info:
#
#  - the observation names that were formed (see `obsnme` column); note that these inlcude lots of usefull metadata like the column name, index value and so on;
#  - the values that were read from `heads.csv` (see `obsval` column);
#  - some generic weights and group names; note that observations are grouped according to the column of the model output .csv. Alternatively, we could have specified a list of observation group names.

# %%
hds_df.head()
# Out:
#                                                                                                 obsnme  \
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0      oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0
#
#                                                        obsval  weight  \
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0    34.263200     1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0  34.527784     1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0  34.444690     1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0  34.318916     1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0  34.178947     1.0
#
#                                                                                      obgnme
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0    oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0  oname:hds_otype:lst_usecol:trgw_0_13_10

# %% [markdown]
# At this point, no PEST *control file* has been created, we have simply prepared to add these observations to the control file later. Everything is still only stored in memory. However, a PEST *instruction* file has been created in the template folder (`template_ws`):

# %%
[f for f in os.listdir(template_ws) if f.endswith(".ins")]
# Out:
# ['heads.csv.ins']

# %% [markdown]
# Blimey, wasn't that easy? Automatically assimilating thousands of observations into a PEST dataset becomes a breeze!
#
# Let's quickly do the same thing for the SFR observations.

# %%
df = pd.read_csv(os.path.join(template_ws, "sfr.csv"), index_col=0)
df.head()
# Out:
#        HEADWATER  TAILWATER  GAGE_1
# time
# 1.0      -644.22    -478.38  1206.1
# 32.0     -860.70    -629.34  1623.6
# 61.0    -1030.30    -758.85  1929.1
# 92.0    -1111.80    -819.40  2060.8
# 122.0   -1082.70    -794.62  1982.8

# %%
# read the measured  values
meas = pd.read_csv(os.path.join('..', '..', 'models', 'freyberg_mf6_truth',"sfr.meas.csv"),
                    index_col=0)
# re-write the model output .csv file with the measured values
meas.to_csv(os.path.join(template_ws,"sfr.csv"))
# add the observations to pf
sfr_df = pf.add_observations("sfr.csv", # the model output file to read
                            insfile="sfr.csv.ins", #optional, the instruction file name
                            index_cols="time", #column header to use as index; can also use column number (zero-based) instead of the header name
                            use_cols=list(df.columns.values), #names of columns that include observation values; can also use column number (zero-based) instead of the header name
                            prefix="sfr") #prefix to all observation names
# Out:
# 2022-02-18 11:08:43.260920 starting: adding observations from output file sfr.csv
# 2022-02-18 11:08:43.260920 starting: adding observations from tabular output file '['sfr.csv']'
# 2022-02-18 11:08:43.260920 starting: reading list-style file: freyberg6_template\sfr.csv
# 2022-02-18 11:08:43.266902 finished: reading list-style file: freyberg6_template\sfr.csv took: 0:00:00.005982
# 2022-02-18 11:08:43.266902 starting: building insfile for tabular output file sfr.csv
# 2022-02-18 11:08:43.274881 finished: building insfile for tabular output file sfr.csv took: 0:00:00.007979
# 2022-02-18 11:08:43.274881 starting: adding observation from instruction file 'freyberg6_template\sfr.csv.ins'
# 2022-02-18 11:08:43.284856 finished: adding observation from instruction file 'freyberg6_template\sfr.csv.ins' took: 0:00:00.009975
# 2022-02-18 11:08:43.285854 finished: adding observations from tabular output file '['sfr.csv']' took: 0:00:00.024934

# %% [markdown]
# ### 5. Parameters
#
# The `PstFrom.add_parameters()` method reads model input files and adds parameters to the PEST(++) dataset. Parameterisation can be configured in several ways.
#
#  - model input files can be in array or list format;
#  - parameters can be setup as different "types". Values in model input files can (1) each be a separate parameter, (2) be grouped into "zones" or (3) all be treated as a single parameter. Alteratvely, (4) parameters can be assigned to pilot points, from which individual parameter values are subsequently interpolated. `PstFrom` adds the relevant pre-processing steps to assign paramter values directly into the "model run" script.
#  - parameter values can be setup as "direct", "multiplier" or "addend". This means the "parameter value" which PEST(++) sees can be (1) the same value the model sees, (2) a multiplier on the value in the model input file, or (3) a value which is added to the value in the model input file. This is very nifty. `PstFrom` is designed to preferentially use parameters setup as multipliers. These let us preserve the existing model inputs and treat them as the mean of the prior parameter distribution. Once again, relevant pre-processing scripts are automatically added to the "model run" script (discussed later).
#
#
# #### 5.1. Freyberg Recap
#
# As discussed, all model inputs are stored in external files. Some are arrays. Others are lists. Recall that our model has 3 layers. It is transient. Hydraulic properties (Kh, Kv, Ss, Sy) vary in space. Recharge varies over both space and time. We have GHBs, SFR and WEL boundary conditions. GHB parameters are constant over time, but vary spatially. SFR inflow varies over time. Pumping rates of individual wells are uncertain in space and and time.
#
# All of these have some degree of spatial and/or temporal correlation.
#
# #### 5.2. Geostatistical Structures
#
# Parameter correlation plays a role in (1) regularization when giving preference to the emergence of patterns of spatial heterogeneity and (2) when specifying the prior parameter probability distribution. Since we are all sophisticated and recognize the importance of expressing spatial and temporal uncertainty (e.g. heterogeneity) in the model inputs (and the corresponding spatial correlation in those uncertain inputs), let's use geostatistics to express uncertainty. To do that we need to define "geostatistical structures".
#
# For the sake of this tutorial, let's assume that heterogeneity in all spatially distributed parameters share the same statistical characteristics. Likewise for temporally varying parameters. We will therefore only  construct two geostatisitcal structures.

# %%
# exponential variogram for spatially varying parameters
v_space = pyemu.geostats.ExpVario(contribution=1.0, #sill
                                    a=1000, # range of correlation; length units of the model. In our case 'meters'
                                    anisotropy=1.0, #name says it all
                                    bearing=0.0 #angle in degrees East of North corresponding to anisotropy ellipse
                                    )

# geostatistical structure for spatially varying parameters
grid_gs = pyemu.geostats.GeoStruct(variograms=v_space, transform='log') 

# plot the gs if you like:
grid_gs.plot()
# Out:
# <AxesSubplot:xlabel='distance', ylabel='$\\gamma$'>

# %%
# exponential variogram for time varying parameters
v_time = pyemu.geostats.ExpVario(contribution=1.0, #sill
                                    a=60, # range of correlation; length time units (days)
                                    anisotropy=1.0, #do not change for 1-D time
                                    bearing=0.0 #do not change for 1-D time
                                    )

# geostatistical structure for time varying parameters
temporal_gs = pyemu.geostats.GeoStruct(variograms=v_time, transform='none')

# %% [markdown]
# #### 5.3. Add Parameters
#
# Let's start by adding parameters of hydraulic properties that vary in space (but not time) and which are housed in array-type files (e.g. Kh, Kv, Ss, Sy). We will start by demonstrating step-by-step for Kh.
#
# First, find all the external array files that contain Kh values. In our case, these are the files with "npf_k_" in the file name. As you can see below, there is one file for each model layer.

# %%
tag = "npf_k_"
files = [f for f in os.listdir(template_ws) if tag in f.lower() and f.endswith(".txt")]
print(files)
# Out:
# ['freyberg6.npf_k_layer1.txt', 'freyberg6.npf_k_layer2.txt', 'freyberg6.npf_k_layer3.txt']

# %% [markdown]
# Let's setup multiple spatial scales of parameters for Kh. To do this we will use three of the parameter "types" described above. The coarse scale will be a `constant` single value for each array. The medium scale will `pilot points`. The finest scale will use parameters as the `grid` scale (a unique parameter for each model cell!)
#
# Each scale of parameters will work with the others as multipliers with the existing Kh arrays. (This all happens at runtime as part of the "model run" script.) Think of the scales as dials that PEST(++) can turn to improve the fit. The "coarse" scale is one big dial that alows PEST to move everything at once. The "medium" dials are few (but not too many) that allow PEST to adjust broad areas, but not making eveything move. The "fine" scales are lots of small dials that allow PEST(++) to have very detailed control, tweaking parameter values within very small areas.
#
# However, because we are working with parameter `multipliers`, we will need to specify two sets of parameter bounds:
#  - `upper_bound` and `lower_bound` are the standard control file bounds, while
#  - `ult_ubound` and `ult_lbound` are bounds that are applied at runtime to the resulting (multiplied out) model input array.
#
# Since we are using sets of multipliers, it is important to make sure we keep the resulting model input arrays within the range of realistic values.
#
# #### 5.3.1. Array Files
#
# We will first demonstrate steb-by-step for `freyberg6.npf_k_layer1.txt`. We will start with grid scale parameters. These are multipliers assigned to each individual value in the array.
#
# We start by getting the idomain array. As our model has inactive cells, this heps us avoid adding unncessary parameters. It is also required later when generating pilot points.

# %%
# as IDOMIAN is the same in all layers, we can use any layer
ib = gwf.dis.idomain.get_data(layer=0)

# %%
f = 'freyberg6.npf_k_layer1.txt'

# grid (fine) scale parameters
df_gr = pf.add_parameters(f,
                zone_array=ib, #as we have inactie model cells, we can avoid assigning these as parameters
                par_type="grid", #specify the type, these will be unique parameters for each cell
                geostruct=grid_gs, # the gestatisical structure for spatial correlation 
                par_name_base=f.split('.')[1]+"_gr", #specify a parameter name base that allows us to easily identify the filename and parameter type. "_gr" for "grid", and so forth.
                pargp=f.split('.')[1]+"_gr", #likewise for the parameter group name
                lower_bound=0.2, upper_bound=5.0, #parameter lower and upper bound
                ult_ubound=100, ult_lbound=0.01 # The ultimate bounds for multiplied model input values. Here we are stating that, after accounting for all multipliers, Kh cannot exceed these values. Very important with multipliers
                )
# Out:
# 2022-02-18 11:08:43.664640 starting: adding grid type m style parameters for file(s) ['freyberg6.npf_k_layer1.txt']
# 2022-02-18 11:08:43.664640 starting: loading array freyberg6_template\freyberg6.npf_k_layer1.txt
# 2022-02-18 11:08:43.671617 finished: loading array freyberg6_template\freyberg6.npf_k_layer1.txt took: 0:00:00.006977
# 2022-02-18 11:08:43.672647 loaded array 'freyberg_mf6\freyberg6.npf_k_layer1.txt' of shape (40, 20)
# 2022-02-18 11:08:43.674610 starting: writing array-style template file 'freyberg6_template\npf_k_layer1_gr_inst0_grid.csv.tpl'
# 2022-02-18 11:08:43.674610 starting: writing template file freyberg6_template\npf_k_layer1_gr_inst0_grid.csv.tpl for ['npf_k_layer1_gr_inst:0']
# 2022-02-18 11:08:43.687574 finished: writing template file freyberg6_template\npf_k_layer1_gr_inst0_grid.csv.tpl for ['npf_k_layer1_gr_inst:0'] took: 0:00:00.012964
# 2022-02-18 11:08:43.687574 starting: writing array-based template file 'freyberg6_template\npf_k_layer1_gr_inst0_grid.csv.tpl'
# 2022-02-18 11:08:43.687574 saving zone array freyberg6_template\npf_k_layer1_gr_inst0_grid.csv.zone for tpl file freyberg6_template\npf_k_layer1_gr_inst0_grid.csv.tpl
# 2022-02-18 11:08:43.697032 finished: adding grid type m style parameters for file(s) ['freyberg6.npf_k_layer1.txt'] took: 0:00:00.032392

# %% [markdown]
# As when adding observations,  `pf.add_parameters()` returns a dataframe. Take a look. You may recognize alot of the information that appears in a PEST `*parameter data` section. All of this is still only housed in memory for now. We will write the PEST control file later on.

# %%
df_gr.head()
# Out:
#                                                                                                                                                               parnme  \
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1    pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1    pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1    pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1    pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1  pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1
#
#                                                                                    parval1  \
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1       1.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1       1.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1       1.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1       1.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1      1.0
#
#                                                                                    i  \
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1   0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1   0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1   0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1   0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1  0
#
#                                                                                    j  \
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1   0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1   1
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1   2
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1   3
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1  4
#
#                                                                                         x  \
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1    125.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1    375.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1    625.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1    875.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1  1125.0
#
#                                                                                         y  \
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1   9875.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1   9875.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1   9875.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1   9875.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1  9875.0
#
#                                                                                              pargp  \
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1   npf_k_layer1_gr
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1   npf_k_layer1_gr
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1   npf_k_layer1_gr
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1   npf_k_layer1_gr
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1  npf_k_layer1_gr
#
#                                                                                                                             tpl_filename  \
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1   freyberg6_template\npf_k_layer1_gr_inst0_grid.csv.tpl
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1   freyberg6_template\npf_k_layer1_gr_inst0_grid.csv.tpl
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1   freyberg6_template\npf_k_layer1_gr_inst0_grid.csv.tpl
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1   freyberg6_template\npf_k_layer1_gr_inst0_grid.csv.tpl
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1  freyberg6_template\npf_k_layer1_gr_inst0_grid.csv.tpl
#
#                                                                                                                            input_filename  \
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1   freyberg6_template\mult\npf_k_layer1_gr_inst0_grid.csv
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1   freyberg6_template\mult\npf_k_layer1_gr_inst0_grid.csv
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1   freyberg6_template\mult\npf_k_layer1_gr_inst0_grid.csv
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1   freyberg6_template\mult\npf_k_layer1_gr_inst0_grid.csv
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1  freyberg6_template\mult\npf_k_layer1_gr_inst0_grid.csv
#
#                                                                                   partype  \
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1     grid
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1     grid
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1     grid
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1     grid
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1    grid
#
#                                                                                   partrans  \
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1       log
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1       log
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1       log
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1       log
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1      log
#
#                                                                                    parubnd  \
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1       5.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1       5.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1       5.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1       5.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1      5.0
#
#                                                                                    parlbnd  \
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1       0.2
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1       0.2
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1       0.2
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1       0.2
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1      0.2
#
#                                                                                    scale  \
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1     1.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1     1.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1     1.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1     1.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1    1.0
#
#                                                                                    offset  \
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1      0.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1      0.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1      0.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1      0.0
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1     0.0
#
#                                                                                    dercom  \
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1        1
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1        1
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1        1
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1        1
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1       1
#
#                                                                                   parchglim
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:0_x:125.00_y:9875.00_zone:1     factor
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:1_x:375.00_y:9875.00_zone:1     factor
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:2_x:625.00_y:9875.00_zone:1     factor
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:3_x:875.00_y:9875.00_zone:1     factor
# pname:npf_k_layer1_gr_inst:0_ptype:gr_pstyle:m_i:0_j:4_x:1125.00_y:9875.00_zone:1    factor

# %% [markdown]
# Now, we add pilot point (medium scale) multiplier parameters to the same model input file. These multipliers are assigned to pilot points, which are subsequently interpolated to values in the array.
#
# You can add pilot points in two ways:
#
# 1. `PstFrom` can generate them for you on a regular grid or
# 2. you can supply `PstFrom` with existing pilot point location information.
#
# When you change `par_type` to "pilotpoints", by default, a regular grid of pilot points is setup using a default `pp_space` value of 10 (which is every 10th row and column). You can chnge this spacing by passing a integer to `pp_space` (as demonstrated below).
#
# Alternatively you can specify a filename or dataframe with pilot point locations. If you supply `pp_space` as a `str` it is assumed to be a filename. The extension is the guide: ".csv" for dataframe, ".shp" for shapefile (point-type). Anything else and the file is assumed to be a pilot points file type. The dataframe (or .csv file) must have "name", "x", and "y" as columns - it can have more, but must have those.

# %%
# pilot point (medium) scale parameters
df_pp = pf.add_parameters(f,
                    zone_array=ib,
                    par_type="pilotpoints",
                    geostruct=grid_gs,
                    par_name_base=f.split('.')[1]+"_pp",
                    pargp=f.split('.')[1]+"_pp",
                    lower_bound=0.2,upper_bound=5.0,
                    ult_ubound=100, ult_lbound=0.01,
                    pp_space=4) # `PstFrom` will generate a unifrom grid of pilot points in every 4th row and column
# Out:
# 2022-02-18 11:08:43.743523 starting: adding pilotpoints type m style parameters for file(s) ['freyberg6.npf_k_layer1.txt']
# 2022-02-18 11:08:43.743523 starting: loading array freyberg6_template\freyberg6.npf_k_layer1.txt
# 2022-02-18 11:08:43.745520 finished: loading array freyberg6_template\freyberg6.npf_k_layer1.txt took: 0:00:00.001997
# 2022-02-18 11:08:43.745520 loaded array 'freyberg_mf6\freyberg6.npf_k_layer1.txt' of shape (40, 20)
# 2022-02-18 11:08:43.747513 starting: writing array-style template file 'freyberg6_template\npf_k_layer1_pp_inst0_pilotpoints.csv.tpl'
# 2022-02-18 11:08:43.747513 starting: setting up pilot point parameters
# 2022-02-18 11:08:43.747513 No spatial reference (containing cell spacing) passed.
# 2022-02-18 11:08:43.747513 OK - using spatial reference in parent object.
# 2022-02-18 11:08:43.820599 32 pilot point parameters created
# 2022-02-18 11:08:43.821562 pilot point 'pargp':npf_k_layer1_pp
# 2022-02-18 11:08:43.821562 finished: setting up pilot point parameters took: 0:00:00.074049
# 2022-02-18 11:08:43.828543 starting: calculating factors for pargp=npf_k_layer1_pp
# 2022-02-18 11:08:43.828543 saving krige variance file:freyberg6_template\npf_k_layer1_pp_inst0pp.var.dat
# 2022-02-18 11:08:43.828543 saving krige factors file:freyberg6_template\npf_k_layer1_pp_inst0pp.fac
# starting interp point loop for 706 points
# starting 0
# starting 1
# starting 2
# starting 3
# starting 4
# starting 5
# starting 6
# starting 7
# starting 8
# starting 9
# took 16.221781 seconds
# 2022-02-18 11:09:00.097227 finished: calculating factors for pargp=npf_k_layer1_pp took: 0:00:16.268684
# 2022-02-18 11:09:00.097227 starting: writing array-based template file 'freyberg6_template\npf_k_layer1_pp_inst0pp.dat.tpl'
# 2022-02-18 11:09:00.097227 saving zone array freyberg6_template\npf_k_layer1_pp_inst0pp.dat.zone for tpl file freyberg6_template\npf_k_layer1_pp_inst0pp.dat.tpl
# 2022-02-18 11:09:00.102214 finished: adding pilotpoints type m style parameters for file(s) ['freyberg6.npf_k_layer1.txt'] took: 0:00:16.358691

# %% [markdown]
# Lastly, add the constant (coarse) parameter multiplier. This is a single multiplier value applied to all values in the array.

# %%
# constant (coarse) scale parameters
df_cst = pf.add_parameters(f,
                    zone_array=ib,
                    par_type="constant",
                    geostruct=grid_gs,
                    par_name_base=f.split('.')[1]+"_cn",
                    pargp=f.split('.')[1]+"_cn",
                    lower_bound=0.2,upper_bound=5.0,
                    ult_ubound=100, ult_lbound=0.01)
# Out:
# 2022-02-18 11:09:00.122127 starting: adding constant type m style parameters for file(s) ['freyberg6.npf_k_layer1.txt']
# 2022-02-18 11:09:00.122127 starting: loading array freyberg6_template\freyberg6.npf_k_layer1.txt
# 2022-02-18 11:09:00.125123 finished: loading array freyberg6_template\freyberg6.npf_k_layer1.txt took: 0:00:00.002996
# 2022-02-18 11:09:00.125123 loaded array 'freyberg_mf6\freyberg6.npf_k_layer1.txt' of shape (40, 20)
# 2022-02-18 11:09:00.127149 starting: writing array-style template file 'freyberg6_template\npf_k_layer1_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:00.127149 starting: writing template file freyberg6_template\npf_k_layer1_cn_inst0_constant.csv.tpl for ['npf_k_layer1_cn_inst:0']
# 2022-02-18 11:09:00.135093 finished: writing template file freyberg6_template\npf_k_layer1_cn_inst0_constant.csv.tpl for ['npf_k_layer1_cn_inst:0'] took: 0:00:00.007944
# 2022-02-18 11:09:00.135093 starting: writing array-based template file 'freyberg6_template\npf_k_layer1_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:00.135093 saving zone array freyberg6_template\npf_k_layer1_cn_inst0_constant.csv.zone for tpl file freyberg6_template\npf_k_layer1_cn_inst0_constant.csv.tpl
# 2022-02-18 11:09:00.143104 finished: adding constant type m style parameters for file(s) ['freyberg6.npf_k_layer1.txt'] took: 0:00:00.020977

# %% [markdown]
# Let's do that for Kh in the other layers. We are going to be doing this a few times, so lets write a function.

# %%
def add_mult_pars(f, lb=0.2, ub=5.0, ulb=0.01, uub=100):
    # grid (fine) scale parameters
    pf.add_parameters(f,
                    zone_array=ib,
                    par_type="grid", #specify the type, these will be unique parameters for each cell
                    geostruct=grid_gs, # the gestatisical structure for spatial correlation 
                    par_name_base=f.split('.')[1]+"_gr", #specify a parameter name base that allows us to easily identify the filename and parameter type. "_gr" for "grid", and so forth.
                    pargp=f.split('.')[1]+"_gr", #likewise for the parameter group name
                    lower_bound=lb, upper_bound=ub, #parameter lower and upper bound
                    ult_ubound=uub, ult_lbound=ulb # The ultimate bounds for multiplied model input values. Here we are stating that, after accounting for all multipliers, Kh cannot exceed these values. Very important with multipliers
                    )
                    
    # pilot point (medium) scale parameters
    pf.add_parameters(f,
                        zone_array=ib,
                        par_type="pilotpoints",
                        geostruct=grid_gs,
                        par_name_base=f.split('.')[1]+"_pp",
                        pargp=f.split('.')[1]+"_pp",
                        lower_bound=lb, upper_bound=ub,
                        ult_ubound=uub, ult_lbound=ulb,
                        pp_space=4) # `PstFrom` will generate a unifrom grid of pilot points in every 4th row and column

    # constant (coarse) scale parameters
    pf.add_parameters(f,
                        zone_array=ib,
                        par_type="constant",
                        geostruct=grid_gs,
                        par_name_base=f.split('.')[1]+"_cn",
                        pargp=f.split('.')[1]+"_cn",
                        lower_bound=lb, upper_bound=ub,
                        ult_ubound=uub, ult_lbound=ulb)
    return

# %%
for f in files[1:]:
    add_mult_pars(f, lb=0.2, ub=5.0, ulb=0.01, uub=100)
# Out:
# 2022-02-18 11:09:00.169003 starting: adding grid type m style parameters for file(s) ['freyberg6.npf_k_layer2.txt']
# 2022-02-18 11:09:00.170001 starting: loading array freyberg6_template\freyberg6.npf_k_layer2.txt
# 2022-02-18 11:09:00.178975 finished: loading array freyberg6_template\freyberg6.npf_k_layer2.txt took: 0:00:00.008974
# 2022-02-18 11:09:00.178975 loaded array 'freyberg_mf6\freyberg6.npf_k_layer2.txt' of shape (40, 20)
# 2022-02-18 11:09:00.180970 starting: writing array-style template file 'freyberg6_template\npf_k_layer2_gr_inst0_grid.csv.tpl'
# 2022-02-18 11:09:00.180970 starting: writing template file freyberg6_template\npf_k_layer2_gr_inst0_grid.csv.tpl for ['npf_k_layer2_gr_inst:0']
# 2022-02-18 11:09:00.193935 finished: writing template file freyberg6_template\npf_k_layer2_gr_inst0_grid.csv.tpl for ['npf_k_layer2_gr_inst:0'] took: 0:00:00.012965
# 2022-02-18 11:09:00.193935 starting: writing array-based template file 'freyberg6_template\npf_k_layer2_gr_inst0_grid.csv.tpl'
# 2022-02-18 11:09:00.193935 saving zone array freyberg6_template\npf_k_layer2_gr_inst0_grid.csv.zone for tpl file freyberg6_template\npf_k_layer2_gr_inst0_grid.csv.tpl
# 2022-02-18 11:09:00.201939 finished: adding grid type m style parameters for file(s) ['freyberg6.npf_k_layer2.txt'] took: 0:00:00.032936
# 2022-02-18 11:09:00.201939 starting: adding pilotpoints type m style parameters for file(s) ['freyberg6.npf_k_layer2.txt']
# 2022-02-18 11:09:00.201939 starting: loading array freyberg6_template\freyberg6.npf_k_layer2.txt
# 2022-02-18 11:09:00.202937 finished: loading array freyberg6_template\freyberg6.npf_k_layer2.txt took: 0:00:00.000998
# 2022-02-18 11:09:00.202937 loaded array 'freyberg_mf6\freyberg6.npf_k_layer2.txt' of shape (40, 20)
# 2022-02-18 11:09:00.205903 starting: writing array-style template file 'freyberg6_template\npf_k_layer2_pp_inst0_pilotpoints.csv.tpl'
# 2022-02-18 11:09:00.205903 starting: setting up pilot point parameters
# 2022-02-18 11:09:00.205903 No spatial reference (containing cell spacing) passed.
# 2022-02-18 11:09:00.205903 OK - using spatial reference in parent object.
# 2022-02-18 11:09:00.274754 32 pilot point parameters created
# 2022-02-18 11:09:00.274754 pilot point 'pargp':npf_k_layer2_pp
# 2022-02-18 11:09:00.274754 finished: setting up pilot point parameters took: 0:00:00.068851
# 2022-02-18 11:09:00.281735 starting: writing array-based template file 'freyberg6_template\npf_k_layer2_pp_inst0pp.dat.tpl'
# 2022-02-18 11:09:00
yberg6_template\npf_k_layer3_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:00.463303 saving zone array freyberg6_template\npf_k_layer3_cn_inst0_constant.csv.zone for tpl file freyberg6_template\npf_k_layer3_cn_inst0_constant.csv.tpl
# 2022-02-18 11:09:00.469281 finished: adding constant type m style parameters for file(s) ['freyberg6.npf_k_layer3.txt'] took: 0:00:00.016940

# %% [markdown]
# Well...hot damn, wasn't that easy? Let's speed through the other array parameter files.

# %%
# for Kv
tag = "npf_k33"
files = [f for f in os.listdir(template_ws) if tag in f.lower() and f.endswith(".txt")]
for f in files:
    add_mult_pars(f, lb=0.2, ub=5.0, ulb=0.01, uub=100)

# for Ss
tag = "sto_ss"
files = [f for f in os.listdir(template_ws) if tag in f.lower() and f.endswith(".txt")]
# only for layer 2 and 3; we aren't monsters
for f in files[1:]: 
    add_mult_pars(f, lb=0.2, ub=5.0, ulb=1e-6, uub=1e-3)

# For Sy
tag = "sto_sy"
files = [f for f in os.listdir(template_ws) if tag in f.lower() and f.endswith(".txt")]
# only for layer 1
f = files[0]
add_mult_pars(f, lb=0.2, ub=5.0, ulb=0.01, uub=0.4)
# Out:
# 2022-02-18 11:09:00.488195 starting: adding grid type m style parameters for file(s) ['freyberg6.npf_k33_layer1.txt']
# 2022-02-18 11:09:00.488195 starting: loading array freyberg6_template\freyberg6.npf_k33_layer1.txt
# 2022-02-18 11:09:00.497170 finished: loading array freyberg6_template\freyberg6.npf_k33_layer1.txt took: 0:00:00.008975
# 2022-02-18 11:09:00.497170 loaded array 'freyberg_mf6\freyberg6.npf_k33_layer1.txt' of shape (40, 20)
# 2022-02-18 11:09:00.499165 starting: writing array-style template file 'freyberg6_template\npf_k33_layer1_gr_inst0_grid.csv.tpl'
# 2022-02-18 11:09:00.499165 starting: writing template file freyberg6_template\npf_k33_layer1_gr_inst0_grid.csv.tpl for ['npf_k33_layer1_gr_inst:0']
# 2022-02-18 11:09:00.512163 finished: writing template file freyberg6_template\npf_k33_layer1_gr_inst0_grid.csv.tpl for ['npf_k33_layer1_gr_inst:0'] took: 0:00:00.012998
# 2022-02-18 11:09:00.513126 starting: writing array-based template file 'freyberg6_template\npf_k33_layer1_gr_inst0_grid.csv.tpl'
# 2022-02-18 11:09:00.513126 saving zone array freyberg6_template\npf_k33_layer1_gr_inst0_grid.csv.zone for tpl file freyberg6_template\npf_k33_layer1_gr_inst0_grid.csv.tpl
# 2022-02-18 11:09:00.520141 finished: adding grid type m style parameters for file(s) ['freyberg6.npf_k33_layer1.txt'] took: 0:00:00.031946
# 2022-02-18 11:09:00.521138 starting: adding pilotpoints type m style parameters for file(s) ['freyberg6.npf_k33_layer1.txt']
# 2022-02-18 11:09:00.521138 starting: loading array freyberg6_template\freyberg6.npf_k33_layer1.txt
# 2022-02-18 11:09:00.522137 finished: loading array freyberg6_template\freyberg6.npf_k33_layer1.txt took: 0:00:00.000999
# 2022-02-18 11:09:00.523134 loaded array 'freyberg_mf6\freyberg6.npf_k33_layer1.txt' of shape (40, 20)
# 2022-02-18 11:09:00.525132 starting: writing array-style template file 'freyberg6_template\npf_k33_layer1_pp_inst0_pilotpoints.csv.tpl'
# 2022-02-18 11:09:00.525132 starting: setting up pilot point parameters
# 2022-02-18 11:09:00.525132 No spatial reference (containing cell spacing) passed.
# 2022-02-18 11:09:00.525132 OK - using spatial reference in parent object.
# 2022-02-18 11:09:00.594755 32 pilot point parameters created
# 2022-02-18 11:09:00.594755 pilot point 'pargp':npf_k33_layer1_pp
# 2022-02-18 11:09:00.594755 finished: setting up pilot point parameters took: 0:00:00.069623
# 2022-02-18 11:09:00.600738 starting: writing array-based template file 'freyberg6_template\npf_k33_layer1_pp_inst0pp.dat.tpl'
# 2022-02-18 11:09:00.601737 saving zone array freyberg6_template\npf_k33_layer1_pp_inst0pp.dat.zone for tpl file freyberg6_template\npf_k33_layer1_pp_inst0pp.dat.tpl
# 2022-02-18 11:09:00.606722 finished: adding pilotpoints type m style parameters for file(s) ['freyberg6.npf_k33_layer1.txt'] took: 0:00:00.085584
# 2022-02-18 11:09:00.606722 starting: adding constant type m style parameters for file(s) ['freyberg6.npf_k33_layer1.txt']
# 2022-02-18 11:09:00.606722 starting: loading array freyberg6_template\freyberg6.npf_k33_layer1.txt
# 2022-02-18 11:09:00.608717 finished: loading array freyberg6_template\freyberg6.npf_k33_layer1.txt took: 0:00:00.001995
# 2022-02-18 11:09:00.608717 loaded array 'freyberg_mf6\freyberg6.npf_k33_layer1.txt' of shape (40, 20)
# 2022-02-18 11:09:00.610712 starting: writing array-style template file 'freyberg6_template\npf_k33_layer1_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:00.610712 starting: writing template file freyberg6_template\npf_k33_layer1_cn_inst0_constant.csv.tpl for ['npf_k33_layer1_cn_inst:0']
# 2022-02-18 11:09:00.617695 finished: writing template file freyberg6_template\npf_k33_layer1_cn_inst0_constant.csv.tpl for ['npf_k33_layer1_cn_inst:0'] took: 0:00:00.006983
# 2022-02-18 11:09:00.617695 starting: writing array-based template file 'freyberg6_template\npf_k33_layer1_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:00.617695 saving zone array freyberg6_template\npf_k33_layer1_cn_inst0_constant.csv.zone for tpl file freyberg6_template\npf_k33_layer1_cn_inst0_constant.csv.tpl
# 2022-02-18 11:09:00.623657 finished: adding constant type m style parameters for file(s) ['freyberg6.npf_k33_layer1.txt'] took: 0:00:00.016935
# 2022-02-18 11:09:00.623657 starting: adding grid type m style parameters for file(s) ['freyberg6.npf_k33_layer2.txt']
# 2022-02-18 11:09:00.623657 starting: loading array freyberg6_template\freyberg6.npf_k33_layer2.txt
# 2022-02-18 11:09:00.630658 finished: loading array freyberg6_template\freyberg6.npf_k33_layer2.txt took: 0:00:00.007001
# 2022-02-18 11:09:00.630658 loaded array 'freyberg_mf6\freyberg6.npf_k33_layer2.txt' of shape (40, 20)
# 2022-02-18 11:09:00.631657 starting: writing array-style template file 'freyberg6_template\npf_k33_layer2_gr_inst0_grid.csv.tpl'
# 2022-02-18 11:09:00.632664 starting: writing template file freyberg6_template\npf_k33_layer2_gr_inst0_grid.csv.tpl for ['npf_k33_layer2_gr_inst:0']
# 2022-02-18 11:09:00.644622 finished: writing template file freyberg6_template\npf_k33_layer2_gr_inst0_grid.csv
loading array freyberg6_template\freyberg6.npf_k33_layer3.txt
# 2022-02-18 11:09:00.870610 finished: loading array freyberg6_template\freyberg6.npf_k33_layer3.txt took: 0:00:00.000996
# 2022-02-18 11:09:00.870610 loaded array 'freyberg_mf6\freyberg6.npf_k33_layer3.txt' of shape (40, 20)
# 2022-02-18 11:09:00.872552 starting: writing array-style template file 'freyberg6_template\npf_k33_layer3_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:00.872552 starting: writing template file freyberg6_template\npf_k33_layer3_cn_inst0_constant.csv.tpl for ['npf_k33_layer3_cn_inst:0']
# 2022-02-18 11:09:00.880531 finished: writing template file freyberg6_template\npf_k33_layer3_cn_inst0_constant.csv.tpl for ['npf_k33_layer3_cn_inst:0'] took: 0:00:00.007979
# 2022-02-18 11:09:00.880531 starting: writing array-based template file 'freyberg6_template\npf_k33_layer3_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:00.880531 saving zone array freyberg6_template\npf_k33_layer3_cn_inst0_constant.csv.zone for tpl file freyberg6_template\npf_k33_layer3_cn_inst0_constant.csv.tpl
# 2022-02-18 11:09:00.886556 finished: adding constant type m style parameters for file(s) ['freyberg6.npf_k33_layer3.txt'] took: 0:00:00.016942
# 2022-02-18 11:09:00.887537 starting: adding grid type m style parameters for file(s) ['freyberg6.sto_ss_layer2.txt']
# 2022-02-18 11:09:00.887537 starting: loading array freyberg6_template\freyberg6.sto_ss_layer2.txt
# 2022-02-18 11:09:00.893528 finished: loading array freyberg6_template\freyberg6.sto_ss_layer2.txt took: 0:00:00.005991
# 2022-02-18 11:09:00.894528 loaded array 'freyberg_mf6\freyberg6.sto_ss_layer2.txt' of shape (40, 20)
# 2022-02-18 11:09:00.895545 starting: writing array-style template file 'freyberg6_template\sto_ss_layer2_gr_inst0_grid.csv.tpl'
# 2022-02-18 11:09:00.896533 starting: writing template file freyberg6_template\sto_ss_layer2_gr_inst0_grid.csv.tpl for ['sto_ss_layer2_gr_inst:0']
# 2022-02-18 11:09:00.908456 finished: writing template file freyberg6_template\sto_ss_layer2_gr_inst0_grid.csv.tpl for ['sto_ss_layer2_gr_inst:0'] took: 0:00:00.011923
# 2022-02-18 11:09:00.908456 starting: writing array-based template file 'freyberg6_template\sto_ss_layer2_gr_inst0_grid.csv.tpl'
# 2022-02-18 11:09:00.908456 saving zone array freyberg6_template\sto_ss_layer2_gr_inst0_grid.csv.zone for tpl file freyberg6_template\sto_ss_layer2_gr_inst0_grid.csv.tpl
# 2022-02-18 11:09:00.916470 finished: adding grid type m style parameters for file(s) ['freyberg6.sto_ss_layer2.txt'] took: 0:00:00.028933
# 2022-02-18 11:09:00.916470 starting: adding pilotpoints type m style parameters for file(s) ['freyberg6.sto_ss_layer2.txt']
# 2022-02-18 11:09:00.916470 starting: loading array freyberg6_template\freyberg6.sto_ss_layer2.txt
# 2022-02-18 11:09:00.917493 finished: loading array freyberg6_template\freyberg6.sto_ss_layer2.txt took: 0:00:00.001023
# 2022-02-18 11:09:00.917493 loaded array 'freyberg_mf6\freyberg6.sto_ss_layer2.txt' of shape (40, 20)
# 2022-02-18 11:09:00.919479 starting: writing array-style template file 'freyberg6_template\sto_ss_layer2_pp_inst0_pilotpoints.csv.tpl'
# 2022-02-18 11:09:00.920462 starting: setting up pilot point parameters
# 2022-02-18 11:09:00.920462 No spatial reference (containing cell spacing) passed.
# 2022-02-18 11:09:00.920462 OK - using spatial reference in parent object.
# 2022-02-18 11:09:00.987130 32 pilot point parameters created
# 2022-02-18 11:09:00.988147 pilot point 'pargp':sto_ss_layer2_pp
# 2022-02-18 11:09:00.988147 finished: setting up pilot point parameters took: 0:00:00.067685
# 2022-02-18 11:09:00.995113 starting: writing array-based template file 'freyberg6_template\sto_ss_layer2_pp_inst0pp.dat.tpl'
# 2022-02-18 11:09:00.995113 saving zone array freyberg6_template\sto_ss_layer2_pp_inst0pp.dat.zone for tpl file freyberg6_template\sto_ss_layer2_pp_inst0pp.dat.tpl
# 2022-02-18 11:09:01.001060 finished: adding pilotpoints type m style parameters for file(s) ['freyberg6.sto_ss_layer2.txt'] took: 0:00:00.084590
# 2022-02-18 11:09:01.001060 starting: adding constant type m style parameters for file(s) ['freyberg6.sto_ss_layer2.txt']
# 2022-02-18 11:09:01.001060 starting: loading array freyberg6_template\freyberg6.sto_ss_layer2.txt
# 2022-02-18 11:09:01.002058 finished: loading array freyberg6_template\freyberg6.sto_ss_layer2.txt took: 0:00:00.000998
# 2022-02-18 11:09:01.003055 loaded array 'freyberg_mf6\freyberg6.sto_ss_layer2.txt' of shape (40, 20)
# 2022-02-18 11:09:01.005083 starting: writing array-style template file 'freyberg6_template\sto_ss_layer2_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:01.005083 starting: writing template file freyberg6_template\sto_ss_layer2_cn_inst0_constant.csv.tpl for ['sto_ss_layer2_cn_inst:0']
# 2022-02-18 11:09:01.012063 finished: writing template file freyberg6_template\sto_ss_layer2_cn_inst0_constant.csv.tpl for ['sto_ss_layer2_cn_inst:0'] took: 0:00:00.006980
# 2022-02-18 11:09:01.012063 starting: writing array-based template file 'freyberg6_template\sto_ss_layer2_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:01.013028 saving zone array freyberg6_template\sto_ss_layer2_cn_inst0_constant.csv.zone for tpl file freyberg6_template\sto_ss_layer2_cn_inst0_constant.csv.tpl
# 2022-02-18 11:09:01.018067 finished: adding constant type m style parameters for file(s) ['freyberg6.sto_ss_layer2.txt'] took: 0:00:00.017007
# 2022-02-18 11:09:01.019044 starting: adding grid type m style parameters for file(s) ['freyberg6.sto_ss_layer3.tx
starting: adding pilotpoints type m style parameters for file(s) ['freyberg6.sto_sy_layer1.txt']
# 2022-02-18 11:09:01.184752 starting: loading array freyberg6_template\freyberg6.sto_sy_layer1.txt
# 2022-02-18 11:09:01.186800 finished: loading array freyberg6_template\freyberg6.sto_sy_layer1.txt took: 0:00:00.002048
# 2022-02-18 11:09:01.186800 loaded array 'freyberg_mf6\freyberg6.sto_sy_layer1.txt' of shape (40, 20)
# 2022-02-18 11:09:01.188792 starting: writing array-style template file 'freyberg6_template\sto_sy_layer1_pp_inst0_pilotpoints.csv.tpl'
# 2022-02-18 11:09:01.188792 starting: setting up pilot point parameters
# 2022-02-18 11:09:01.188792 No spatial reference (containing cell spacing) passed.
# 2022-02-18 11:09:01.188792 OK - using spatial reference in parent object.
# 2022-02-18 11:09:01.256592 32 pilot point parameters created
# 2022-02-18 11:09:01.256592 pilot point 'pargp':sto_sy_layer1_pp
# 2022-02-18 11:09:01.257591 finished: setting up pilot point parameters took: 0:00:00.068799
# 2022-02-18 11:09:01.263593 starting: writing array-based template file 'freyberg6_template\sto_sy_layer1_pp_inst0pp.dat.tpl'
# 2022-02-18 11:09:01.264594 saving zone array freyberg6_template\sto_sy_layer1_pp_inst0pp.dat.zone for tpl file freyberg6_template\sto_sy_layer1_pp_inst0pp.dat.tpl
# 2022-02-18 11:09:01.269577 finished: adding pilotpoints type m style parameters for file(s) ['freyberg6.sto_sy_layer1.txt'] took: 0:00:00.084825
# 2022-02-18 11:09:01.269577 starting: adding constant type m style parameters for file(s) ['freyberg6.sto_sy_layer1.txt']
# 2022-02-18 11:09:01.269577 starting: loading array freyberg6_template\freyberg6.sto_sy_layer1.txt
# 2022-02-18 11:09:01.270522 finished: loading array freyberg6_template\freyberg6.sto_sy_layer1.txt took: 0:00:00.000945
# 2022-02-18 11:09:01.270522 loaded array 'freyberg_mf6\freyberg6.sto_sy_layer1.txt' of shape (40, 20)
# 2022-02-18 11:09:01.273567 starting: writing array-style template file 'freyberg6_template\sto_sy_layer1_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:01.273567 starting: writing template file freyberg6_template\sto_sy_layer1_cn_inst0_constant.csv.tpl for ['sto_sy_layer1_cn_inst:0']
# 2022-02-18 11:09:01.279556 finished: writing template file freyberg6_template\sto_sy_layer1_cn_inst0_constant.csv.tpl for ['sto_sy_layer1_cn_inst:0'] took: 0:00:00.005989
# 2022-02-18 11:09:01.279556 starting: writing array-based template file 'freyberg6_template\sto_sy_layer1_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:01.280530 saving zone array freyberg6_template\sto_sy_layer1_cn_inst0_constant.csv.zone for tpl file freyberg6_template\sto_sy_layer1_cn_inst0_constant.csv.tpl
# 2022-02-18 11:09:01.286532 finished: adding constant type m style parameters for file(s) ['freyberg6.sto_sy_layer1.txt'] took: 0:00:00.016955

# %% [markdown]
# #### 5.3.2. Spatial and Temporal Correlation
#
# Now, you may be thinking "shouldn't recharge have temporal correlation as well?".
#
# Damn straight it should. Now, this requires a little trickery.
#
# First we need to construct a container of stress period datetimes. (This relies on specifying the start_datetime argument when instantiating `PstFrom`.) These datetime values will specify the postion of parameters on the time-axis.

# %%
# build up a container of stress period start datetimes - this will
# be used to specify the datetime of each multipler parameter
start_datetime="1-1-2018"
dts = pd.to_datetime(start_datetime) + pd.to_timedelta(np.cumsum(sim.tdis.perioddata.array["perlen"]),unit='d')

dts
# Out:
# DatetimeIndex(['2018-01-02', '2018-02-02', '2018-03-03', '2018-04-03',
#                '2018-05-03', '2018-06-03', '2018-07-03', '2018-08-03',
#                '2018-09-03', '2018-10-03', '2018-11-03', '2018-12-03',
#                '2019-01-03', '2019-02-03', '2019-03-03', '2019-04-03',
#                '2019-05-03', '2019-06-03', '2019-07-03', '2019-08-03',
#                '2019-09-03', '2019-10-03', '2019-11-03', '2019-12-03',
#                '2020-01-03'],
#               dtype='datetime64[ns]', freq=None)

# %% [markdown]
# If you use the same parameter group name (`pargp`) and same geostruct, `PstFrom` will treat parameters setup across different calls to `add_parameters()` as correlated.  In this case, we want to express temporal correlation in the recharge multiplier parameters. So, we use the same parameter group names for each stress period data file, and specify the `datetime` and `geostruct` arguments.
#
# Including temporal correlation introduces an additional challenge. Interpolation between points that share a common coordinate creates all types of trouble. We are going to have many parameters during each stress period (a single point on the time-axis). To get around this challenge we need to be a bit sneaky.
#
#
# First, we will apply the multiple *spatial* scales of parameter multiplers (`constant`, `pilot point` and `grid`) as we did for hyraulic properties.
#
# Then, we will asign an additional `constant` multiplier parameter for each recharge stress-period file (so, a single multiplier for all recharge paramaters for each stress period). We will specify temporal correlation for these `constant` multipliers. These will all have the same parameter group name, as discussed above.

# %%
# for Recharge; 
tag = "rch_recharge"
files = [f for f in os.listdir(template_ws) if tag in f.lower() and f.endswith(".txt")]
for f in files:
    # the spatial multiplier parameters; just use the same function
    add_mult_pars(f, lb=0.2, ub=5.0, ulb=2e-5, uub=2e-4)
    
    
    # multiplier that includes temporal correlation
    # get the stress period number from the file name
    kper = int(f.split('.')[1].split('_')[-1]) - 1  
    
    # add the constant parameters (with temporal correlation)
    pf.add_parameters(filenames=f,
                    zone_array=ib,
                    par_type="constant",
                    par_name_base=f.split('.')[1]+"_tcn",
                    pargp=f.split('.')[1]+"_tcn",
                    lower_bound=0.5, upper_bound=1.5,
                    ult_ubound=2e-4, ult_lbound=2e-5,
                    datetime=dts[kper], # this places the parameter value on the "time axis"
                    geostruct=temporal_gs)
# Out:
# 2022-02-18 11:09:01.325041 starting: adding grid type m style parameters for file(s) ['freyberg6.rch_recharge_1.txt']
# 2022-02-18 11:09:01.326039 starting: loading array freyberg6_template\freyberg6.rch_recharge_1.txt
# 2022-02-18 11:09:01.332023 finished: loading array freyberg6_template\freyberg6.rch_recharge_1.txt took: 0:00:00.005984
# 2022-02-18 11:09:01.332023 loaded array 'freyberg_mf6\freyberg6.rch_recharge_1.txt' of shape (40, 20)
# 2022-02-18 11:09:01.334019 starting: writing array-style template file 'freyberg6_template\rch_recharge_1_gr_inst0_grid.csv.tpl'
# 2022-02-18 11:09:01.334019 starting: writing template file freyberg6_template\rch_recharge_1_gr_inst0_grid.csv.tpl for ['rch_recharge_1_gr_inst:0']
# 2022-02-18 11:09:01.347034 finished: writing template file freyberg6_template\rch_recharge_1_gr_inst0_grid.csv.tpl for ['rch_recharge_1_gr_inst:0'] took: 0:00:00.013015
# 2022-02-18 11:09:01.347034 starting: writing array-based template file 'freyberg6_template\rch_recharge_1_gr_inst0_grid.csv.tpl'
# 2022-02-18 11:09:01.348014 saving zone array freyberg6_template\rch_recharge_1_gr_inst0_grid.csv.zone for tpl file freyberg6_template\rch_recharge_1_gr_inst0_grid.csv.tpl
# 2022-02-18 11:09:01.354998 finished: adding grid type m style parameters for file(s) ['freyberg6.rch_recharge_1.txt'] took: 0:00:00.029957
# 2022-02-18 11:09:01.354998 starting: adding pilotpoints type m style parameters for file(s) ['freyberg6.rch_recharge_1.txt']
# 2022-02-18 11:09:01.355959 starting: loading array freyberg6_template\freyberg6.rch_recharge_1.txt
# 2022-02-18 11:09:01.356992 finished: loading array freyberg6_template\freyberg6.rch_recharge_1.txt took: 0:00:00.001033
# 2022-02-18 11:09:01.356992 loaded array 'freyberg_mf6\freyberg6.rch_recharge_1.txt' of shape (40, 20)
# 2022-02-18 11:09:01.358983 starting: writing array-style template file 'freyberg6_template\rch_recharge_1_pp_inst0_pilotpoints.csv.tpl'
# 2022-02-18 11:09:01.358983 starting: setting up pilot point parameters
# 2022-02-18 11:09:01.358983 No spatial reference (containing cell spacing) passed.
# 2022-02-18 11:09:01.358983 OK - using spatial reference in parent object.
# 2022-02-18 11:09:01.431115 32 pilot point parameters created
# 2022-02-18 11:09:01.432076 pilot point 'pargp':rch_recharge_1_pp
# 2022-02-18 11:09:01.432076 finished: setting up pilot point parameters took: 0:00:00.073093
# 2022-02-18 11:09:01.439168 starting: writing array-based template file 'freyberg6_template\rch_recharge_1_pp_inst0pp.dat.tpl'
# 2022-02-18 11:09:01.439168 saving zone array freyberg6_template\rch_recharge_1_pp_inst0pp.dat.zone for tpl file freyberg6_template\rch_recharge_1_pp_inst0pp.dat.tpl
# 2022-02-18 11:09:01.445041 finished: adding pilotpoints type m style parameters for file(s) ['freyberg6.rch_recharge_1.txt'] took: 0:00:00.090043
# 2022-02-18 11:09:01.445041 starting: adding constant type m style parameters for file(s) ['freyberg6.rch_recharge_1.txt']
# 2022-02-18 11:09:01.445041 starting: loading array freyberg6_template\freyberg6.rch_recharge_1.txt
# 2022-02-18 11:09:01.446038 finished: loading array freyberg6_template\freyberg6.rch_recharge_1.txt took: 0:00:00.000997
# 2022-02-18 11:09:01.446038 loaded array 'freyberg_mf6\freyberg6.rch_recharge_1.txt' of shape (40, 20)
# 2022-02-18 11:09:01.448033 starting: writing array-style template file 'freyberg6_template\rch_recharge_1_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:01
yberg6_template\rch_recharge_9_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:05.133034 starting: writing template file freyberg6_template\rch_recharge_9_cn_inst0_constant.csv.tpl for ['rch_recharge_9_cn_inst:0']
# 2022-02-18 11:09:05.141012 finished: writing template file freyberg6_template\rch_recharge_9_cn_inst0_constant.csv.tpl for ['rch_recharge_9_cn_inst:0'] took: 0:00:00.007978
# 2022-02-18 11:09:05.141012 starting: writing array-based template file 'freyberg6_template\rch_recharge_9_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:05.141012 saving zone array freyberg6_template\rch_recharge_9_cn_inst0_constant.csv.zone for tpl file freyberg6_template\rch_recharge_9_cn_inst0_constant.csv.tpl
# 2022-02-18 11:09:05.146996 finished: adding constant type m style parameters for file(s) ['freyberg6.rch_recharge_9.txt'] took: 0:00:00.019946
# 2022-02-18 11:09:05.147995 starting: adding constant type m style parameters for file(s) ['freyberg6.rch_recharge_9.txt']
# 2022-02-18 11:09:05.147995 starting: loading array freyberg6_template\freyberg6.rch_recharge_9.txt
# 2022-02-18 11:09:05.148991 finished: loading array freyberg6_template\freyberg6.rch_recharge_9.txt took: 0:00:00.000996
# 2022-02-18 11:09:05.148991 loaded array 'freyberg_mf6\freyberg6.rch_recharge_9.txt' of shape (40, 20)
# 2022-02-18 11:09:05.150986 starting: writing array-style template file 'freyberg6_template\rch_recharge_9_tcn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:05.150986 starting: writing template file freyberg6_template\rch_recharge_9_tcn_inst0_constant.csv.tpl for ['rch_recharge_9_tcn_inst:0']
# 2022-02-18 11:09:05.158965 finished: writing template file freyberg6_template\rch_recharge_9_tcn_inst0_constant.csv.tpl for ['rch_recharge_9_tcn_inst:0'] took: 0:00:00.007979
# 2022-02-18 11:09:05.158965 starting: writing array-based template file 'freyberg6_template\rch_recharge_9_tcn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:05.159962 saving zone array freyberg6_template\rch_recharge_9_tcn_inst0_constant.csv.zone for tpl file freyberg6_template\rch_recharge_9_tcn_inst0_constant.csv.tpl
# 2022-02-18 11:09:05.169936 finished: adding constant type m style parameters for file(s) ['freyberg6.rch_recharge_9.txt'] took: 0:00:00.021941

# %% [markdown]
# ### 5.3.3. List Files
#
# Adding parameters from list-type files follows similar principles. As with observation files, they must be tabular. Certain columns are specified as index columns and are used to populate parameter names, as well as provide the parameters' spatial location. Other columns are specified as containing parameter values.
#
# Parameters can be `grid` or `constant`. As before, values can be assigned `directly`, as `multipliers` or as `additives`.
#
# We will demonstrate for the boundary-condition input files.
#
# Starting off with GHBs. Let's inspect the folder. As you can see, there is a single input file (GHB parameters are assumed to not vary over time).

# %%
tag = "ghb_stress_period_data"
files = [f for f in os.listdir(template_ws) if tag in f.lower() and f.endswith(".txt")]
print(files)
# Out:
# ['freyberg6.ghb_stress_period_data_1.txt']

# %% [markdown]
# Since these boundaries are likely to be very influential, we want to include a robust representation of their uncertainty - both head and conductance and at multiple scales.
#
# Let's parameterize both GHB conductance and head:
#
#  - For conductance, we shall use two scales of `multiplier` parameters (`constant` and `grid`).
#
#  - For heads, multipliers are not ideal. Insead we will use `additive` parameters. Again, with a coarse and fine scale.

# %%
tag = "ghb_stress_period_data"
files = [f for f in os.listdir(template_ws) if tag in f.lower() and f.endswith(".txt")]

for f in files:
    # constant and grid scale multiplier conductance parameters
    name = 'ghbcond'
    pf.add_parameters(f,
                        par_type="grid",
                        geostruct=grid_gs,
                        par_name_base=name+"_gr",
                        pargp=name+"_gr",
                        index_cols=[0,1,2], #column containing lay,row,col
                        use_cols=[4], #column containing conductance values
                        lower_bound=0.1,upper_bound=10.0,
                        ult_lbound=0.1, ult_ubound=100) #absolute limits
    pf.add_parameters(f,
                        par_type="constant",
                        geostruct=grid_gs,
                        par_name_base=name+"_cn",
                        pargp=name+"_cn",
                        index_cols=[0,1,2],
                        use_cols=[4],  
                        lower_bound=0.1,upper_bound=10.0,
                        ult_lbound=0.1, ult_ubound=100) #absolute limits

    # constant and grid scale additive head parameters
    name = 'ghbhead'
    pf.add_parameters(f,
                        par_type="grid",
                        geostruct=grid_gs,
                        par_name_base=name+"_gr",
                        pargp=name+"_gr",
                        index_cols=[0,1,2],
                        use_cols=[3],   # column containing head values
                        lower_bound=-2.0,upper_bound=2.0,
                        par_style="a", # specify additive parameter
                        transform="none") # specify not log-transform
    pf.add_parameters(f,
                        par_type="constant",
                        geostruct=grid_gs,
                        par_name_base=name+"_cn",
                        pargp=name+"_cn",
                        index_cols=[0,1,2],
                        use_cols=[3],
                        lower_bound=-2.0,upper_bound=2.0, 
                        par_style="a", 
                        transform="none")
# Out:
# 2022-02-18 11:09:05.251716 starting: adding grid type m style parameters for file(s) ['freyberg6.ghb_stress_period_data_1.txt']
# 2022-02-18 11:09:05.251716 starting: loading list-style freyberg6_template\freyberg6.ghb_stress_period_data_1.txt
# 2022-02-18 11:09:05.251716 starting: reading list-style file: freyberg6_template\freyberg6.ghb_stress_period_data_1.txt
# 2022-02-18 11:09:05.253711 finished: reading list-style file: freyberg6_template\freyberg6.ghb_stress_period_data_1.txt took: 0:00:00.001995
# 2022-02-18 11:09:05.253711 loaded list-style 'freyberg6_template\freyberg6.ghb_stress_period_data_1.txt' of shape (30, 5)
# 2022-02-18 11:09:05.256702 finished: loading list-style freyberg6_template\freyberg6.ghb_stress_period_data_1.txt took: 0:00:00.004986
# 2022-02-18 11:09:05.256702 starting: writing list-style template file 'freyberg6_template\ghbcond_gr_inst0_grid.csv.tpl'
# 2022-02-18 11:09:05.261689 WARNING: get_xy() warning: position of i and j in index_cols not specified, assume (i,j) are final two entries in index_cols.
# 2022-02-18 11:09:05.266676 WARNING: Coincidently located pars in list-style file, attempting to separate pars based on `index_cols` passed - using index_col[0] for third dimension
# 2022-02-18 11:09:05.276649 finished: writing list-style template file 'freyberg6_template\ghbcond_gr_inst0_grid.csv.tpl' took: 0:00:00.019947
# 2022-02-18 11:09:05.282633 finished: adding grid type m style parameters for file(s) ['freyberg6.ghb_stress_period_data_1.txt'] took: 0:00:00.030917
# 2022-02-18 11:09:05.282633 starting: adding constant type m style parameters for file(s) ['freyberg6.ghb_stress_period_data_1.txt']
# 2022-02-18 11:09:05.282633 starting: loading list-style freyberg6_template\freyberg6.ghb_stress_period_data_1.txt
# 2022-02-18 11:09:05.282633 starting: reading list-style file: freyberg6_template\freyberg6.ghb_stress_period_data_1.txt
# 2022-02-18 11:09:05.284628 finished: reading list-style file: freyberg6_template\freyberg6.ghb_stress_period_data_1.txt took: 0:00:00.001995
# 2022-02-18 11:09:05.284628 loaded list-style 'freyberg6_template\freyberg6.ghb_stress_period_data_1.txt' of shape (30, 5)
# 2022-02-18 11:09:05.285625 finished: loading list-style freyberg6_template\freyberg6.ghb_stress_period_data_1.txt took: 0:00:00.002992
# 2022-02-18 11:09:05.285625 starting: writing list-style template file 'freyberg6_template\ghbcond_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:05.299588 finished: writing list-style template file 'freyberg6_template\ghbcond_cn_inst0_constant.csv.tpl' took: 0:00:00.013963
# 2022-02-18 11:09:05.305689 finished: adding constant type m style parameters for file(s) ['freyberg6.ghb_stress_period_data_1.txt'] took: 0:00:00.023056
# 2022-02-18 11:09:05.305689 starting: adding grid type a style parameters for file(s) ['freyberg6.ghb_stress_period_data_1.txt']
# 2022-02-18 11:09:05.305689 WARNING: 0) Inconsistency between geostruct transform and partrans.
# 2022-02-18 11:09:05.305689 WARNING: 1) Setting geostruct transform to {transform}
# 2022-02-18 11:09:05.305689 WARNING: 2) This will create a new copy of geostruct
# 2022-02-18 11:09:05.305689 WARNING: -) Better to pass an appropriately transformed geostruct
# 2022-02-18 11:09:05.305689 starting: loading list-style freyberg6_template\freyberg6.ghb_stress_period_data_1.txt
# 2022-02-18 11:09:05.305689 starting: reading list-style file: freyberg6_template\freyberg6.ghb_stress_period_data_1.txt
# 2022-02-18 11:09:05.307600 finished: reading list-style file: freyberg6_template\freyberg6.ghb_stress_period_data_1.txt took: 0:00:00.001911
# 2022-02-18 11:09:05.308599 loaded list-style 'freyberg6_template\freyberg6.ghb_stress_period_data_1.txt' of shape (30, 5)
# 2022-02-18 11:09:05.309602 finished: loading list-style freyberg6_template\freyberg6.ghb_stress_period_data_1.txt took: 0:00:00.003913
# 2022-02-18 11:09:05.309602 starting: writing list-style template file 'freyberg6_template\ghbhead_gr_inst0_grid.csv.tpl'
# 2022-02-18 11:09:05.314583 WARNING: get_xy() warning: position of i and j in index_cols not specified, assume (i,j) are final two entries in index_cols.
# 2022-02-18 11:09:05.319536 WARNING: Coincidently located pars in list-style file, attempting to separate pars based on `index_cols` passed - using index_col[0] for third dimension
# 2022-02-18 11:09:05.330506 finished: writing list-style template file 'freyberg6_template\ghbhead_gr_inst0_grid.csv.tpl' took: 0:00:00.020904
# 2022-02-18 11:09:05.336526 finished: adding grid type a style parameters for file(s) ['freyberg6.ghb_stress_period_data_1.txt'] took: 0:00:00.030837
# 2022-02-18 11:09:05.336526 starting: adding constant type a style parameters for file(s) ['freyberg6.ghb_stress_period_data_1.txt']
# 2022-02-18 11:09:05.336526 WARNING: 0) Inconsistency between geostruct transform and partrans.
# 2022-02-18 11:09:05.336526 WARNING: 1) Setting geostruct transform to {transform}
# 2022-02-18 11:09:05.336526 WARNING: 2) This will create a new copy of geostruct
# 2022-02-18 11:09:05.336526 WARNING: -) Better to pass an appropriately transformed geostruct
# 2022-02-18 11:09:05.336526 starting: loading list-style freyberg6_template\freyberg6.ghb_stress_period_data_1.txt
# 2022-02-18 11:09:05.336526 starting: reading list-style file: freyberg6_template\freyberg6.ghb_stress_period_data_1.txt
# 2022-02-18 11:09:05.339515 finished: reading list-style file: freyberg6_template\freyberg6.ghb_stress_period_data_1.txt took: 0:00:00.002989
# 2022-02-18 11:09:05.339515 loaded list-style 'freyberg6_template\freyberg6.ghb_stress_period_data_1.txt' of shape (30, 5)
# 2022-02-18 11:09:05.340512 finished: loading list-style freyberg6_template\freyberg6.ghb_stress_period_data_1.txt took: 0:00:00.003986
# 2022-02-18 11:09:05.340512 starting: writing list-style template file 'freyberg6_template\ghbhead_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:05.353444 finished: writing list-style template file 'freyberg6_template\ghbhead_cn_inst0_constant.csv.tpl' took: 0:00:00.012932
# 2022-02-18 11:09:05.359428 finished: adding constant type a style parameters for file(s) ['freyberg6.ghb_stress_period_data_1.txt'] took: 0:00:00.022902

# %% [markdown]
# Easy peasy.
#
# Now this will make some people uncomfortable but how well do we really ever know historic water use flux rates in space and in time? hmmm, not really! So lets add parameters to represent that uncertainty in the model inputs.
#
# For wells it may not (or it may...) make sense to include spatial correlation. Here we will assume temporal correlation - its reasonable that pumping rates today will be similar to pumping rates yesterday.
#
# Pumping rates for different stress periods are in separate files. We will call `.add_parameters()` for each file. But we want to specify correlation between parameters in different files. As explained above for recharge, we do this with the parameter group name.
#
# OK, let's get started.

# %% [markdown]
# As discussed above, including temporal correlation introduces an additional challenge. We use the same approach described for recharge parmaeters:
#
# First, we will asign a `constant` multiplier parameter for each WEL stress-period file (so, a single multiplier for all well pumping rates for each stress period). We will specify temporal correlation for these `constant` multipliers.
#
# Then, we will also have `grid` type multiplier parameters for each WEL stress period file (so, multipliers for individual well pumping rate during each stress period). These will not include correlation. (We could in principle include spatial correlation here if we wanted to; but let's not).

# %%
files = [f for f in os.listdir(template_ws) if "wel_stress_period_data" in f and f.endswith(".txt")]

for f in files:
    # get the stress period number from the file name
    kper = int(f.split('.')[1].split('_')[-1]) - 1  
    
    # add the constant parameters (with temporal correlation)
    pf.add_parameters(filenames=f,
                        index_cols=[0,1,2], #columns that specify cell location
                        use_cols=[3],       #columns with parameter values
                        par_type="constant",    #each well will be adjustable
                        par_name_base="wel_cst",
                        pargp="wel_cst", 
                        upper_bound = 1.5, lower_bound=0.5,
                        datetime=dts[kper], # this places the parameter value on the "time axis"
                        geostruct=temporal_gs)
    
    # add the grid parameters; each individual well
    pf.add_parameters(filenames=f,
                        index_cols=[0,1,2], #columns that specify cell location 
                        use_cols=[3],       #columns with parameter values
                        par_type="grid",    #each well will be adjustable
                        par_name_base="wel_grd",
                        pargp="wel_grd", 
                        upper_bound = 1.5, lower_bound=0.5,
                        datetime=dts[kper]) # this places the parameter value on the "time axis"
# Out:
# 2022-02-18 11:09:05.374388 starting: adding constant type m style parameters for file(s) ['freyberg6.wel_stress_period_data
finished: loading list-style freyberg6_template\freyberg6.wel_stress_period_data_8.txt took: 0:00:00.004986
# 2022-02-18 11:09:06.617066 starting: writing list-style template file 'freyberg6_template\wel_cst_inst23_constant.csv.tpl'
# 2022-02-18 11:09:06.632026 finished: writing list-style template file 'freyberg6_template\wel_cst_inst23_constant.csv.tpl' took: 0:00:00.014960
# 2022-02-18 11:09:06.641003 finished: adding constant type m style parameters for file(s) ['freyberg6.wel_stress_period_data_8.txt'] took: 0:00:00.028923
# 2022-02-18 11:09:06.641003 starting: adding grid type m style parameters for file(s) ['freyberg6.wel_stress_period_data_8.txt']
# 2022-02-18 11:09:06.642000 starting: loading list-style freyberg6_template\freyberg6.wel_stress_period_data_8.txt
# 2022-02-18 11:09:06.642000 starting: reading list-style file: freyberg6_template\freyberg6.wel_stress_period_data_8.txt
# 2022-02-18 11:09:06.643996 finished: reading list-style file: freyberg6_template\freyberg6.wel_stress_period_data_8.txt took: 0:00:00.001996
# 2022-02-18 11:09:06.643996 loaded list-style 'freyberg6_template\freyberg6.wel_stress_period_data_8.txt' of shape (6, 4)
# 2022-02-18 11:09:06.644991 finished: loading list-style freyberg6_template\freyberg6.wel_stress_period_data_8.txt took: 0:00:00.002991
# 2022-02-18 11:09:06.644991 starting: writing list-style template file 'freyberg6_template\wel_grd_inst23_grid.csv.tpl'
# 2022-02-18 11:09:06.658954 finished: writing list-style template file 'freyberg6_template\wel_grd_inst23_grid.csv.tpl' took: 0:00:00.013963
# 2022-02-18 11:09:06.667930 finished: adding grid type m style parameters for file(s) ['freyberg6.wel_stress_period_data_8.txt'] took: 0:00:00.026927
# 2022-02-18 11:09:06.667930 starting: adding constant type m style parameters for file(s) ['freyberg6.wel_stress_period_data_9.txt']
# 2022-02-18 11:09:06.667930 starting: loading list-style freyberg6_template\freyberg6.wel_stress_period_data_9.txt
# 2022-02-18 11:09:06.668927 starting: reading list-style file: freyberg6_template\freyberg6.wel_stress_period_data_9.txt
# 2022-02-18 11:09:06.670922 finished: reading list-style file: freyberg6_template\freyberg6.wel_stress_period_data_9.txt took: 0:00:00.001995
# 2022-02-18 11:09:06.670922 loaded list-style 'freyberg6_template\freyberg6.wel_stress_period_data_9.txt' of shape (6, 4)
# 2022-02-18 11:09:06.671919 finished: loading list-style freyberg6_template\freyberg6.wel_stress_period_data_9.txt took: 0:00:00.003989
# 2022-02-18 11:09:06.671919 starting: writing list-style template file 'freyberg6_template\wel_cst_inst24_constant.csv.tpl'
# 2022-02-18 11:09:06.684884 finished: writing list-style template file 'freyberg6_template\wel_cst_inst24_constant.csv.tpl' took: 0:00:00.012965
# 2022-02-18 11:09:06.693861 finished: adding constant type m style parameters for file(s) ['freyberg6.wel_stress_period_data_9.txt'] took: 0:00:00.025931
# 2022-02-18 11:09:06.693861 starting: adding grid type m style parameters for file(s) ['freyberg6.wel_stress_period_data_9.txt']
# 2022-02-18 11:09:06.693861 starting: loading list-style freyberg6_template\freyberg6.wel_stress_period_data_9.txt
# 2022-02-18 11:09:06.693861 starting: reading list-style file: freyberg6_template\freyberg6.wel_stress_period_data_9.txt
# 2022-02-18 11:09:06.695857 finished: reading list-style file: freyberg6_template\freyberg6.wel_stress_period_data_9.txt took: 0:00:00.001996
# 2022-02-18 11:09:06.695857 loaded list-style 'freyberg6_template\freyberg6.wel_stress_period_data_9.txt' of shape (6, 4)
# 2022-02-18 11:09:06.696853 finished: loading list-style freyberg6_template\freyberg6.wel_stress_period_data_9.txt took: 0:00:00.002992
# 2022-02-18 11:09:06.697850 starting: writing list-style template file 'freyberg6_template\wel_grd_inst24_grid.csv.tpl'
# 2022-02-18 11:09:06.711813 finished: writing list-style template file 'freyberg6_template\wel_grd_inst24_grid.csv.tpl' took: 0:00:00.013963
# 2022-02-18 11:09:06.720789 finished: adding grid type m style parameters for file(s) ['freyberg6.wel_stress_period_data_9.txt'] took: 0:00:00.026928

# %% [markdown]
# And finally, our favourite (not!) boundary-condition: SFR.
#
# Let's parameterize conductance (time-invariant) and inflow (time-variant).

# %%
# SFR conductance
tag = "sfr_packagedata"
files = [f for f in os.listdir(template_ws) if tag in f.lower() and f.endswith(".txt")]
assert len(files) == 1 # There can be only one! It is tradition. Jokes.
print(files)
f = files[0]
# constant and grid scale multiplier conductance parameters
name = "sfrcond"
pf.add_parameters(f,
                par_type="grid",
                geostruct=grid_gs,
                par_name_base=name+"_gr",
                pargp=name+"_gr",
                index_cols=[0,2,3],
                use_cols=[9],
                lower_bound=0.1,upper_bound=10.0,
                ult_lbound=0.01, ult_ubound=10) #absolute limits
pf.add_parameters(f,
                par_type="constant",
                geostruct=grid_gs,
                par_name_base=name+"_cn",
                pargp=name+"_cn",
                index_cols=[0,2,3],
                use_cols=[9],
                lower_bound=0.1,upper_bound=10.0,
                ult_lbound=0.01, ult_ubound=10) #absolute limits
# Out:
# ['freyberg6.sfr_packagedata.txt']
# 2022-02-18 11:09:06.742730 starting: adding grid type m style parameters for file(s) ['freyberg6.sfr_packagedata.txt']
# 2022-02-18 11:09:06.743727 starting: loading list-style freyberg6_template\freyberg6.sfr_packagedata.txt
# 2022-02-18 11:09:06.743727 starting: reading list-style file: freyberg6_template\freyberg6.sfr_packagedata.txt
# 2022-02-18 11:09:06.746720 finished: reading list-style file: freyberg6_template\freyberg6.sfr_packagedata.txt took: 0:00:00.002993
# 2022-02-18 11:09:06.746720 loaded list-style 'freyberg6_template\freyberg6.sfr_packagedata.txt' of shape (40, 15)
# 2022-02-18 11:09:06.748714 finished: loading list-style freyberg6_template\freyberg6.sfr_packagedata.txt took: 0:00:00.004987
# 2022-02-18 11:09:06.748714 starting: writing list-style template file 'freyberg6_template\sfrcond_gr_inst0_grid.csv.tpl'
# 2022-02-18 11:09:06.753700 WARNING: get_xy() warning: position of i and j in index_cols not specified, assume (i,j) are final two entries in index_cols.
# 2022-02-18 11:09:06.771653 finished: writing list-style template file 'freyberg6_template\sfrcond_gr_inst0_grid.csv.tpl' took: 0:00:00.022939
# 2022-02-18 11:09:06.777637 finished: adding grid type m style parameters for file(s) ['freyberg6.sfr_packagedata.txt'] took: 0:00:00.034907
# 2022-02-18 11:09:06.777637 starting: adding constant type m style parameters for file(s) ['freyberg6.sfr_packagedata.txt']
# 2022-02-18 11:09:06.778634 starting: loading list-style freyberg6_template\freyberg6.sfr_packagedata.txt
# 2022-02-18 11:09:06.778634 starting: reading list-style file: freyberg6_template\freyberg6.sfr_packagedata.txt
# 2022-02-18 11:09:06.781626 finished: reading list-style file: freyberg6_template\freyberg6.sfr_packagedata.txt took: 0:00:00.002992
# 2022-02-18 11:09:06.781626 loaded list-style 'freyberg6_template\freyberg6.sfr_packagedata.txt' of shape (40, 15)
# 2022-02-18 11:09:06.782623 finished: loading list-style freyberg6_template\freyberg6.sfr_packagedata.txt took: 0:00:00.003989
# 2022-02-18 11:09:06.782623 starting: writing list-style template file 'freyberg6_template\sfrcond_cn_inst0_constant.csv.tpl'
# 2022-02-18 11:09:06.796586 finished: writing list-style template file 'freyberg6_template\sfrcond_cn_inst0_constant.csv.tpl' took: 0:00:00.013963
# 2022-02-18 11:09:06.801573 finished: adding constant type m style parameters for file(s) ['freyberg6.sfr_packagedata.txt'] took: 0:00:00.023936
#                                                                                                 parnme  \
# pname:sfrcond_cn_inst:0_ptype:cn_usecol:9_pstyle:m  pname:sfrcond_cn_inst:0_ptype:cn_usecol:9_pstyle:m
#
#                                                          pargp       covgp  \
# pname:sfrcond_cn_inst:0_ptype:cn_usecol:9_pstyle:m  sfrcond_cn  sfrcond_cn
#
#                                                                                             tpl_filename  \
# pname:sfrcond_cn_inst:0_ptype:cn_usecol:9_pstyle:m  freyberg6_template\sfrcond_cn_inst0_constant.csv.tpl
#
#                                                                                            input_filename  \
# pname:sfrcond_cn_inst:0_ptype:cn_usecol:9_pstyle:m  freyberg6_template\mult\sfrcond_cn_inst0_constant.csv
#
#                                                     parval1   partype  \
# pname:sfrcond_cn_inst:0_ptype:cn_usecol:9_pstyle:m      1.0  constant
#
#                                                    partrans  parubnd  parlbnd  \
# pname:sfrcond_cn_inst:0_ptype:cn_usecol:9_pstyle:m      log     10.0      0.1
#
#                                                     scale  offset  dercom  \
# pname:sfrcond_cn_inst:0_ptype:cn_usecol:9_pstyle:m    1.0     0.0       1
#
#                                                    parchglim
# pname:sfrcond_cn_inst:0_ptype:cn_usecol:9_pstyle:m    factor

# %%
# SFR inflow
files = [f for f in os.listdir(template_ws) if "sfr_perioddata" in f and f.endswith(".txt")]
for f in files:
    # get the stress period number from the file name
    kper = int(f.split('.')[1].split('_')[-1]) - 1  
    # add the parameters
    pf.add_parameters(filenames=f,
                        index_cols=[0], #reach number
                        use_cols=[2],   #columns with parameter values
                        par_type="grid",    
                        par_name_base="sfr_gr",
                        pargp="sfr_gr", 
                        upper_bound = 1.5, lower_bound=0.5, #don't need ult_bounds because it is a single multiplier
                        datetime=dts[kper], # this places the parameter value on the "time axis"
                        geostruct=temporal_gs)
# Out:
# 2022-02-18 11:09:06.821520 starting: adding grid type m style parameters for file(s) ['freyberg6.sfr_perioddata_1.txt']
# 2022-02-18 11:09:06.821520 starting: loading list-style freyberg6_template\freyberg6.sfr_perioddata_1.txt
# 2022-02-18 11:09:06.822518 starting: reading list-style file: freyberg6_template\freyberg6.sfr_perioddata_1.txt
# 2022-02-18 11:09:06.824513 finished: reading list-style file: freyberg6_template\freyberg6.sfr_perioddata_1.txt took: 0:00:00.001995
# 2022-02-18 11:09:06.824513 loaded list-style 'freyberg6_template\freyberg6.sfr_perioddata_1.txt' of shape (1, 3)
# 2022-02-18 11:09:06.826507 finished: loading list-style freyberg6_template\freyberg6.sfr_perioddata_1.txt took: 0:00:00.004987
# 2022-02-18 11:09:06.826507 starting: writing list-style template file 'freyberg6_template\sfr_gr_inst0_grid.csv.tpl'
# 2022-02-18 11:09:06.832491 WARNING: get_xy() warning: need locational information (e.g. i,j) to generate xy, insufficient index cols passed to interpret: (0,)
# 2022-02-18 11:09:06.847453 finished: writing list-style template file 'freyberg6_template\sfr_gr_inst0_grid.csv.tpl' took: 0:00:00.020946
# 2022-02-18 11:09:06.856426 finished: adding grid type m style parameters for file(s) ['freyberg6.sfr_perioddata_1.txt'] took: 0:00:00.034906
# 2022-02-18 11:09:06.857424 starting: adding grid type m style parameters for file(s) ['freyberg6.sfr_perioddata_10.txt']
# 2022-02-18 11:09:06.857424 starting: loading list-style freyberg6_template\freyberg6.sfr_perioddata_10.txt
# 2022-02-18 11:09:06.857424 starting: reading list-style file: freyberg6_template\freyberg6.sfr_perioddata_10.txt
# 2022-02-18 11:09:06.859418 finished: reading list-style file: freyberg6_template\freyberg6.sfr_perioddata_10.txt took: 0:00:00.001994
# 2022-02-18 11:09:06.859418 loaded list-style 'freyberg6_template\freyberg6.sfr_perioddata_10.txt' of shape (1, 3)
# 2022-02-18 11:09:06.860415 finished: loading list-style freyberg6_template\freyberg6.sfr_perioddata_10.txt took: 0:00:00.002991
# 2022-02-18 11:09:06.860415 starting: writing list-style template file 'freyberg6_template\sfr_gr_inst1_grid.csv.tpl'
# 2022-02-18 11:09:06.865402 WARNING: get_xy() warning: need locational information (e.g. i,j) to generate xy, insufficient index cols passed to interpret: (0,)
# 2022-02-18 11:09:06.877371 finished: writing list-style template file 'freyberg6_template\sfr_gr_inst1_grid.csv.tpl' took: 0:00:00.016956
# 2022-02-18 11:09:06.886347 finished: adding grid type m style parameters for file(s) ['freyberg6.sfr_perioddata_10.txt'] took: 0:00:00.028923
# 2022-02-18 11:09:06.887343 starting: adding grid type m style parameters for file(s) ['freyberg6.sfr_perioddata_11.txt']
# 2022-02-18 11:09:06.887343 starting: loading list-style freyberg6_template\freyberg6.sfr_perioddata_11.txt
# 2022-02-18 11:09:06.887343 starting: reading list-style file: freyberg6_template\freyberg6.sfr_perioddata_11.txt
# 2022-02-18 11:09:06.890337 finished: reading list-style file: freyberg6_template\freyberg6.sfr_perioddata_11.txt took: 0:00:00.002994
# 2022-02-18 11:09:06.890337 loaded list-style 'freyberg6_template\freyberg6.sfr_perioddata_11.txt' of shape (1, 3)
# 2022-02-18 11:09:06.891334 finished: loading list-style freyberg6_template\freyberg6.sfr_perioddata_11.txt took: 0:00:00.003991
# 2022-02-18 11:09:06.892331 starting: writing list-style template file 'freyberg6_template\sfr_gr_inst2_grid.csv.tpl'
# 2022-02-18 11:09:06.896320 WARNING: get_xy() warning: need locational information (e.g. i,j) to generate xy, insufficient index cols passed to interpret: (0,)
# 2022-02-18 11:09:06.909286 finished: writing list-style template file 'freyberg6_template\sfr_gr_inst2_grid.csv.tpl' took: 0:00:00.016955
# 2022-02-18 11:09:06.918262 finished: adding grid type m style parameters for file(s) ['freyberg6.sfr_perioddata_11.txt'] took: 0:00:00.030919
# 2022-02-18 11:09:06.918262 starting: adding grid type m style parameters for file(s) ['freyberg6.sfr_perioddata_12.txt']
# 2022-02-18 11:09:06.919259 starting: loading list-style freyberg6_template\freyberg6.sfr_perioddata_12.txt
# 2022-02-18 11:09:06.919259 starting: reading list-style file: freyberg6_template\freyberg6.sfr_perioddata_12.txt
# 2022-02-18 11:09:06.922299 finished: reading list-style file: freyberg6_template\freyberg6.sfr_perioddata_12.txt took: 0:00:00.003040
# 2022-02-18 11:09:06.922299 loaded list-style 'freyberg6_template\freyberg6.sfr_perioddata_12.txt' of shape (1, 3)
# 2022-02-18 11:09:06.923248 finished: loading list-style freyberg6_template\freyberg6.sfr_perioddata_12.txt took: 0:00:00.003989
# 2022-02-18 11:09:06.923248 starting: writing list-style template file 'freyberg6_template\sfr_gr_inst3_grid.csv.tpl'
# 2022-02-18 11:09:06.927238 WARNING: get_xy() warning: need locational information (e.g. i,j) to generate xy, insufficient index cols passed to interpret: (0,)
# 2022-02-18 11:09:06.940203 finished: writing list-style template file 'freyberg6_template\sfr_gr_inst3_grid.csv.tpl' took: 0:00:00.016955
# 2022-02-18 11:09:06.956194 finished: adding grid type m style parameters for file(s) ['freyberg6.sfr_perioddata_12.txt'] took: 0:00:00.037932
# 2022-02-18 11:09:06.956194 starting: adding grid type m style parameters for file(s) ['freyberg6.sfr_perioddata
# OK! So, we almost have all the base building blocks for a PEST(++) dataset. We have some (1) observations and some (2) parameters. We are still missing (3) the "forward run" script. Recall that in the PEST world, the "model" is not just the numerical model (e.g. MODFLOW). Instead it is a composite of the numerical model (or models) and pre- and post-processing steps, encapsulated in a "forward run" script which can be called from the command line. This command line instruction is what PEST(++) sees as "the model". During execution, PEST(++) writes values to parameter files, runs "the model", and then reads values from the observation files.
#
# `PstFrom` automates the generation of such a script when constructing the PEST control file. The script is written to file named `forward_run.py`. It is written in Python (this is not a PEST(++) requirement, merely a convenience...we are working in Python after all...).
#
# How about we see that in action? Magic time! Let's create the PEST control file.
#
# #### 6.1. Build Pst
#
# The `PstFrom.build_pst()` method builds a control file from the `PstFrom` object. It will write a PEST control file to the template folder. It will also write the `forward_run.py` script. It returns a pyEMU `Pst` object with all the information of the PEST control file. You can subsequently edit this `Pst` object. However, (***IMPORTANT***) any subsequent changes to the `Pst` object are not reflected in the `PstFrom` object, or viceversa. If you subsequently use `PstFrom` to add more observation or parameter files, you will need to re-build the `Pst` object. When you do so, all edits to the `Pst` object will be lost. Keep this in mind when designing your workflow.
#
#
# Here we go!
#
# (Note: in a normal workflow, we probably wouldn't do this yet. We are doing so now for demonstration purposes.)

# %%
pst = pf.build_pst()
# Out:
# noptmax:0, npar_adj:25454, nnz_obs:725

# %% [markdown]
# Boom! Done. (Well almost.) Check the folder. You should see a new .pst file and the `forward_run.py` file. By default, the .pst file is named after the original model folder name.

# %%
[f for f in os.listdir(template_ws) if f.endswith(".py") or f.endswith(".pst") ]
# Out:
# ['forward_run.py', 'freyberg_mf6.pst']

# %% [markdown]
# We will get to the `pst` object later on (see also the "intro to pyemu" tutorial notebook). For now, let's focus on the `forward_run.py` script. It is printed out below.
#
# This script does a bunch of things:
#  - it loads necessary dependecies
#  - it removes model output files to avoid the possibility of files from a previous model run being read by mistake;
#  - it runs pre-processing steps (see `pyemu.helpers.apply_list_and_array_pars()`;
#  - it executes system commands (usually running the simulator, i.e. MODFLOW). (*This is still missing. We will demonstrate next.*)
#  - it executes post-processing steps; (*for now there aren't any*)
#  - ...it washes the dishes (sorry, no it doesn't...this feature is still in development).

# %%
_ = [print(line.rstrip()) for line in open(os.path.join(template_ws,"forward_run.py"))]
# Out:
# import os
# import multiprocessing as mp
# import numpy as np
# import pandas as pd
# import pyemu
# def main():
#
#     try:
#        os.remove(r'heads.csv')
#     except Exception as e:
#        print(r'error removing tmp file:heads.csv')
#     try:
#        os.remove(r'sfr.csv')
#     except Exception as e:
#        print(r'error removing tmp file:sfr.csv')
#     pyemu.helpers.apply_list_and_array_pars(arr_par_file='mult2model_info.csv',chunk_len=50)
#
# if __name__ == '__main__':
#     mp.freeze_support()
#     main()

# %% [markdown]
# That's pretty amazing. But as we just saw, we still need to add commands to actualy run the model.
#
# `PstFrom` allows you to pass a list of system commands which will be executed in sequence. It also has methods for including Python functions that run before or after the system commands. These make pre-/post-processing a piece of cake. In fact, we have already started to add to it. Remember all of the multiplier and additive parameters we setup? These all require pre-processing steps to convert the PEST-generated multipliers into model input values. `PstFrom` will automatically add these functions to the `forward_run.py` script. Nifty, hey?
#
# Next we will demonstrate how to specify the system commands and add Python functions as processing steps.
#
# #### 6.2. Sys Commands
#
# Let's start by adding a command line instruction. These are stored as a list in `PstFrom.mod_sys_cmds`, which is currently empty.

# %%
pf.mod_sys_cmds
# Out:
# []

# %% [markdown]
# To run a MODFLOW6 model from the command line, you can simply execute `mf6` in the model folder. So, we can add this command by appending it to the list. (Do this only once! Every time you append 'mf6' results in an additional call to MODFLOW6, meaning the model would be run multiple times.)
#
# `PstFrom` will add a line to `forward_run.py` w

# %%
pf.mod_sys_cmds.append("mf6") #do this only once
pf.mod_sys_cmds
# Out:
# ['mf6']

# %% [markdown]
# OK, now let's re-build the Pst control file and check out the changes ot the `forward_run.py` script.
#
# You should see that `pyemu.os_utils.run(r'mf6')` has been added after the pre-processing functions.

# %%
pst = pf.build_pst()

_ = [print(line.rstrip()) for line in open(os.path.join(template_ws,"forward_run.py"))]
# Out:
# noptmax:0, npar_adj:25454, nnz_obs:725
# 2022-02-18 11:09:11.247763 forward_run line:pyemu.os_utils.run(r'mf6')
#
# import os
# import multiprocessing as mp
# import numpy as np
# import pandas as pd
# import pyemu
# def main():
#
#     try:
#        os.remove(r'heads.csv')
#     except Exception as e:
#        print(r'error removing tmp file:heads.csv')
#     try:
#        os.remove(r'sfr.csv')
#     except Exception as e:
#        print(r'error removing tmp file:sfr.csv')
#     pyemu.helpers.apply_list_and_array_pars(arr_par_file='mult2model_info.csv',chunk_len=50)
#     pyemu.os_utils.run(r'mf6')
#
#
# if __name__ == '__main__':
#     mp.freeze_support()
#     main()

# %% [markdown]
# #### 6.3. Extra pre- and post-processing functions
#
# You will also certainly need to include some additional processing steps.  These are supported thru the `PstFrom.pre_py_cmds` and `PstFrom.post_py_cmds`, which are lists for pre and post model run python commands and `PstFrom.pre_sys_cmds` and `PstFrom.post_sys_cmds`, which are lists for pre and post model run system commands (these are wrapped in `pyemu.os_utils.run()`.
#
# But what if your additional steps are actually an entire python function? Well, we got that too! `PstFrom.add_py_function()`. This method allows you to get functions from another (pre-prepared) python source file and add them to the `forward_run.py` script. We will deonstrate this to post-process secondary model observations after each run.
#
# #### 6.3.1. Secondary Observations
#
# Often it is usefull to include "secondary model outcomes" as observations. These can be important components in a history-matching dataset to tease out specific aspects of system behaviour (e.g. head differences between aquifer layers to inform vertical permeabilities). Or they may be simple summaries of modelled outputs which are of interest for a prediction (e.g. minimum simulated head over a given period).
#
# If you inspect the tutorial folder you will find a file named `helpers.py`. This is a python source file which we have prepared for you. (Open it to see how it is organized.) It contains a function named `process_secondary_obs()`. This function reads the model output .csv files, processes them and writes a series of new observation .csv files. These new files contain (1) the temporal-differences between head and SFR observations, and (2) the difference in heads between the top and bottom layers at each observation point. The new .csv files are named `heads.tdiff.csv`,`sfr.tdiff.csv` and `heads.vdiff.csv` respectively.
#
# First, lets load the function here and run it so you can see what happens. (And to make sure that the observation files are in the template folder!)
#
# Run the next cell, then inspect the template folder. You should see three new csv files. These are the new secondary observations calculated by the post-processing function.

# %%
from helpers import  process_secondary_obs

process_secondary_obs(ws=template_ws)
# Out:
# Secondary observation files processed.

# %%
[f for f in os.listdir(template_ws) if f.endswith(".csv")]
# Out:
# ['heads.csv',
#  'heads.tdiff.csv',
#  'heads.vdiff.csv',
#  'mult2model_info.csv',
#  'sfr.csv',
#  'sfr.tdiff.csv']

# %% [markdown]
# OK, so now let's add this function to the `forward_run.py` script.

# %%
pf.add_py_function("helpers.py", # the file which contains the function
                    "process_secondary_obs(ws='.')", #the function, making sure to specify any arguments it may requrie
                    is_pre_cmd=False) # whether it runs before the model system command, or after. In this case, after.

# %% [markdown]
# And, boom! Bob's your uncle. As easy as that.
#
# Now, of course we want to add these observations to `PstFrom` as well:

# %%
df = pd.read_csv(os.path.join(template_ws, "sfr.tdiff.csv"), index_col=0)
_ = pf.add_observations("sfr.tdiff.csv", # the model output file to read
                            insfile="sfr.tdiff.csv.ins", #optional, the instruction file name
                            index_cols="time", #column header to use as index; can also use column number (zero-based) instead of the header name
                            use_cols=list(df.columns.values), #names of columns that include observation values; can also use column number (zero-based) instead of the header name
                            prefix="sfrtd") #prefix to all observation 
                            
df = pd.read_csv(os.path.join(template_ws, "heads.tdiff.csv"), index_col=0)
_ = pf.add_observations("heads.tdiff.csv", # the model output file to read
                            insfile="heads.tdiff.csv.ins", #optional, the instruction file name
                            index_cols="time", #column header to use as index; can also use column number (zero-based) instead of the header name
                            use_cols=list(df.columns.values), #names of columns that include observation values; can also use column number (zero-based) instead of the header name
                            prefix="hdstd") #prefix to all observation names

df = pd.read_csv(os.path.join(template_ws, "heads.vdiff.csv"), index_col=0)
_ = pf.add_observations("heads.vdiff.csv", # the model output file to read
                            insfile="heads.vdiff.csv.ins", #optional, the instruction file name
                            index_cols="time", #column header to use as index; can also use column number (zero-based) instead of the header name
                            use_cols=list(df.columns.values), #names of columns that include observation values; can also use column number (zero-based) instead of the header name
                            prefix="hdsvd") #prefix to all observation names
# Out:
# 2022-02-18 11:09:11.598944 starting: adding observations from output file sfr.tdiff.csv
# 2022-02-18 11:09:11.598944 starting: adding observations from tabular output file '['sfr.tdiff.csv']'
# 2022-02-18 11:09:11.598944 starting: reading list-style file: freyberg6_template\sfr.tdiff.csv
# 2022-02-18 11:09:11.599947 finished: reading list-style file: freyberg6_template\sfr.tdiff.csv took: 0:00:00.001003
# 2022-02-18 11:09:11.600938 starting: building insfile for tabular output file sfr.tdiff.csv
# 2022-02-18 11:09:11.607914 finished: building insfile for tabular output file sfr.tdiff.csv took: 0:00:00.006976
# 2022-02-18 11:09:11.607914 starting: adding observation from instruction file 'freyberg6_template\sfr.tdiff.csv.ins'
# 2022-02-18 11:09:11.616896 finished: adding observation from instruction file 'freyberg6_template\sfr.tdiff.csv.ins' took: 0:00:00.008982
# 2022-02-18 11:09:11.617892 finished: adding observations from tabular output file '['sfr.tdiff.csv']' took: 0:00:00.018948
# 2022-02-18 11:09:11.626857 starting: adding observations from output file heads.tdiff.csv
# 2022-02-18 11:09:11.626857 starting: adding observations from tabular output file '['heads.tdiff.csv']'
# 2022-02-18 11:09:11.627857 starting: reading list-style file: freyberg6_template\heads.tdiff.csv
# 2022-02-18 11:09:11.629841 finished: reading list-style file: freyberg6_template\heads.tdiff.csv took: 0:00:00.001984
# 2022-02-18 11:09:11.629841 starting: building insfile for tabular output file heads.tdiff.csv
# 2022-02-18 11:09:11.638793 finished: building insfile for tabular output file heads.tdiff.csv took: 0:00:00.008952
# 2022-02-18 11:09:11.638793 starting: adding observation from instruction file 'freyberg6_template\heads.tdiff.csv.ins'
# 2022-02-18 11:09:11.657795 finished: adding observation from instruction file 'freyberg6_template\heads.tdiff.csv.ins' took: 0:00:00.019002
# 2022-02-18 11:09:11.658792 finished: adding observations from tabular output file '['heads.tdiff.csv']' took: 0:00:00.031935
# 2022-02-18 11:09:11.661783 starting: adding observations from output file heads.vdiff.csv
# 2022-02-18 11:09:11.661783 starting: adding observations from tabular output file '['heads.vdiff.csv']'
# 2022-02-18 11:09:11.661783 starting: reading list-style file: freyberg6_template\heads.vdiff.csv
# 2022-02-18 11:09:11.663777 finished: reading list-style file: freyberg6_template\heads.vdiff.csv took: 0:00:00.001994
# 2022-02-18 11:09:11.663777 starting: building insfile for tabular output file heads.vdiff.csv
# 2022-02-18 11:09:11.670765 finished: building insfile for tabular output file heads.vdiff.csv took: 0:00:00.006988
# 2022-02-18 11:09:11.672006 starting: adding observation from instruction file 'freyberg6_template\heads.vdiff.csv.ins'
# 2022-02-18 11:09:11.685720 finished: adding observation from instruction file 'freyberg6_template\heads.vdiff.csv.ins' took: 0:00:00.013714
# 2022-02-18 11:09:11.687724 finished: adding observations from tabular output file '['heads.vdiff.csv']' took: 0:00:00.025941

# %% [markdown]
# Remember to re-build the Pst control file:

# %%
pst = pf.build_pst()
# Out:
# noptmax:0, npar_adj:25454, nnz_obs:1775
# 2022-02-18 11:09:13.343434 WARNING: sys_cmd 'pyemu.os_utils.run(r'mf6')
# ' already in sys cmds, skipping...

# %% [markdown]
# ### 7. After Building the Control File
#
# At this point, we can do some additional modifications that would typically be done that are problem specific.  Here we can tweak the setup, specifying things such as observation weights, parameter bounds, transforms, control data, etc.
#
# Note that any modifications made after calling `PstFrom.build_pst()` will only exist in memory - you need to call `pf.pst.write()` to record these changes to the control file on disk.  Also note that if you call `PstFrom.build_pst()` after making some changes, these changes will be lost.
#
# For the current case, the main thing we haven't addressed are the observation weights. We will do so now.
#
# #### 7.1. Setting observation weights
#
# So far, we have automated the setup for PEST(++).  But one critical task remains and there is not an easy way to automate it:  setting the actual observed values and weights in the `* observation data` information.
#
# `PstFrom` and `Pst` will both try to read existing model output files that correspond to instruction files and put those simulated values into the `* observation data` section for the observed values (the `obsval` quantity).  Here, we pre-populated the model output files with "measured values". So, in our case, we are OK in this regard.  Alternatively, we could have edited the `* observation data` at this stage, assigning the respective measured values into the `obsval` column.
#
# What we are unable to deal with beforehand are the observation weights. Let's take a look at the observation data:

# %%
obs = pst.observation_data
obs
# Out:
#                                                                                                 obsnme  \
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0      oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0
# ...                                                                                                ...
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:640.0  oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:640.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:671.0  oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:671.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:701.0  oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:701.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:732.0  oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:732.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:92.0    oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:92.0
#
#                                                        obsval  weight  \
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0    34.263200     1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0  34.527784     1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0  34.444690     1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0  34.318916     1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0  34.178947     1.0
# ...                                                       ...     ...
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:640.0   0.006110     1.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:671.0   0.005748     1.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:701.0   0.005420     1.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:732.0   0.005233     1.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:92.0    0.006154     1.0
#
#                                                                                      obgnme  \
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0    oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# ...                                                                                     ...
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:640.0  oname:hdsvd_otype:lst_usecol:trgw_0_9_1
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:671.0  oname:hdsvd_otype:lst_usecol:trgw_0_9_1
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:701.0  oname:hdsvd_otype:lst_usecol:trgw_0_9_1
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:732.0  oname:hdsvd_otype:lst_usecol:trgw_0_9_1
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:92.0   oname:hdsvd_otype:lst_usecol:trgw_0_9_1
#
#                                                     oname otype usecol   time
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0      hds   lst   trgw    1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0    hds   lst   trgw  122.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0    hds   lst   trgw  153.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0    hds   lst   trgw  183.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0    hds   lst   trgw  214.0
# ...                                                   ...   ...    ...    ...
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:640.0  hdsvd   lst   trgw  640.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:671.0  hdsvd   lst   trgw  671.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:701.0  hdsvd   lst   trgw  701.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:732.0  hdsvd   lst   trgw  732.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:92.0   hdsvd   lst   trgw   92.0
#
# [1775 rows x 8 columns]

# %% [markdown]
# Hmm, that's alot of observations. And remember, alot of these pertain to the "prediction" period. We definitly do not want those to have an influence on history-matching.
#
# To be on the safe side, let's assign a weight of zero to all observations. Then, we will assign weights to specific observations that we wish to include as history-matching targets.

# %%
# preemptive avoidance of sillyness
obs['weight'] = 0
obs.head()
# Out:
#                                                                                                 obsnme  \
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0      oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0
#
#                                                        obsval  weight  \
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0    34.263200       0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0  34.527784       0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0  34.444690       0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0  34.318916       0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0  34.178947       0
#
#                                                                                      obgnme  \
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0    oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0  oname:hds_otype:lst_usecol:trgw_0_13_10
#
#                                                    oname otype usecol   time
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0     hds   lst   trgw    1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0   hds   lst   trgw  122.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0   hds   lst   trgw  153.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0   hds   lst   trgw  183.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0   hds   lst   trgw  214.0

# %% [markdown]
# Because `PstFrom` is our friend, it kept track of lots of information. We can now use this to help us slice and select specific observations. Scroll though the `obs` columns to see what we have at hand.
#
# For example, the `oname` column stores the "prefix" we assigned eveytime we called `pf.add_observations()`. This makes it easy for us to now select observations according to which file they were read from.
#
# Just as a reminder:

# %%
obs['oname'].unique()
# Out:
# array(['hds', 'sfr', 'sfrtd', 'hdstd', 'hdsvd'], dtype=object)

# %% [markdown]
# So, if we want to select observations from the `heads.csv` file, and that have a time < than 367, we can just use `Pandas` .loc:

# %%
obs.loc[(obs['oname']=='hds') & (obs['time'].astype(float) <= 367)]
# Out:
#                                                                                                 obsnme  \
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0      oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0
# ...                                                                                                ...
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:32.0        oname:hds_otype:lst_usecol:trgw_2_9_1_time:32.0
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:336.0      oname:hds_otype:lst_usecol:trgw_2_9_1_time:336.0
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:367.0      oname:hds_otype:lst_usecol:trgw_2_9_1_time:367.0
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:61.0        oname:hds_otype:lst_usecol:trgw_2_9_1_time:61.0
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:92.0        oname:hds_otype:lst_usecol:trgw_2_9_1_time:92.0
#
#                                                        obsval  weight  \
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0    34.263200       0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0  34.527784       0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0  34.444690       0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0  34.318916       0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0  34.178947       0
# ...                                                       ...     ...
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:32.0     34.972781       0
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:336.0    34.649192       0
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:367.0    34.743288       0
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:61.0     35.083356       0
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:92.0     35.177773       0
#
#                                                                                      obgnme  \
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0    oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# ...                                                                                     ...
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:32.0       oname:hds_otype:lst_usecol:trgw_2_9_1
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:336.0      oname:hds_otype:lst_usecol:trgw_2_9_1
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:367.0      oname:hds_otype:lst_usecol:trgw_2_9_1
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:61.0       oname:hds_otype:lst_usecol:trgw_2_9_1
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:92.0       oname:hds_otype:lst_usecol:trgw_2_9_1
#
#                                                    oname otype usecol   time
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0     hds   lst   trgw    1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0   hds   lst   trgw  122.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0   hds   lst   trgw  153.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0   hds   lst   trgw  183.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0   hds   lst   trgw  214.0
# ...                                                  ...   ...    ...    ...
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:32.0      hds   lst   trgw   32.0
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:336.0     hds   lst   trgw  336.0
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:367.0     hds   lst   trgw  367.0
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:61.0      hds   lst   trgw   61.0
# oname:hds_otype:lst_usecol:trgw_2_9_1_time:92.0      hds   lst   trgw   92.0
#
# [338 rows x 8 columns]

# %% [markdown]
# OK, so now let's use this to assign weights to each observation type. We will set weights to the inverse of the standard deviation of our measurment uncertainty.
#
# Let's say that stdevs for:
#  - head measurements are is 0.1m,
#  - head time an vertical differences 0.01m
#  - SFR direct and time-differnces will be 10% of the measured value

# %%
# direct head measurments
obs.loc[(obs['oname']=='hds') & (obs['time'].astype(float) <= 367), 'weight'] = 1/0.1
# head time differences
obs.loc[(obs['oname']=='hdstd') & (obs['time'].astype(float) <= 367), 'weight'] = 1/0.01
# head vertical differences
obs.loc[(obs['oname']=='hdsvd') & (obs['time'].astype(float) <= 367), 'weight'] = 1/0.01

# %%
# SFR direct measurments
weights = 1 / abs(0.1 * obs.loc[(obs['oname']=='sfr') & (obs['time'].astype(float) <= 367), 'obsval'].values)
obs.loc[(obs['oname']=='sfr') & (obs['time'].astype(float) <= 367), 'weight'] = weights

# SFR time-difference measurments; deal with the first observation value that is == 0
weights = 1 / abs(0.1 * obs.loc[(obs['oname']=='sfrtd') & (obs['time'].astype(float) <= 367) &  (obs['obsval'] !=0) , 'obsval'].values)
obs.loc[(obs['oname']=='sfrtd') & (obs['time'].astype(float) <= 367) &  (obs['obsval'] !=0), 'weight'] = weights

# %% [markdown]
# As you can see, observation data weights have been updated:

# %%
obs
# Out:
#                                                                                                 obsnme  \
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0      oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0  oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0
# ...                                                                                                ...
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:640.0  oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:640.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:671.0  oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:671.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:701.0  oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:701.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:732.0  oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:732.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:92.0    oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:92.0
#
#                                                        obsval  weight  \
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0    34.263200    10.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0  34.527784    10.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0  34.444690    10.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0  34.318916    10.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0  34.178947    10.0
# ...                                                       ...     ...
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:640.0   0.006110     0.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:671.0   0.005748     0.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:701.0   0.005420     0.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:732.0   0.005233     0.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:92.0    0.006154   100.0
#
#                                                                                      obgnme  \
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0    oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0  oname:hds_otype:lst_usecol:trgw_0_13_10
# ...                                                                                     ...
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:640.0  oname:hdsvd_otype:lst_usecol:trgw_0_9_1
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:671.0  oname:hdsvd_otype:lst_usecol:trgw_0_9_1
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:701.0  oname:hdsvd_otype:lst_usecol:trgw_0_9_1
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:732.0  oname:hdsvd_otype:lst_usecol:trgw_0_9_1
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:92.0   oname:hdsvd_otype:lst_usecol:trgw_0_9_1
#
#                                                     oname otype usecol   time
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:1.0      hds   lst   trgw    1.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:122.0    hds   lst   trgw  122.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:153.0    hds   lst   trgw  153.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:183.0    hds   lst   trgw  183.0
# oname:hds_otype:lst_usecol:trgw_0_13_10_time:214.0    hds   lst   trgw  214.0
# ...                                                   ...   ...    ...    ...
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:640.0  hdsvd   lst   trgw  640.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:671.0  hdsvd   lst   trgw  671.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:701.0  hdsvd   lst   trgw  701.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:732.0  hdsvd   lst   trgw  732.0
# oname:hdsvd_otype:lst_usecol:trgw_0_9_1_time:92.0   hdsvd   lst   trgw   92.0
#
# [1775 rows x 8 columns]

# %% [markdown]
# Make sure to re-**write** the PEST control file. But beware, if you re-**build** the `Pst`, all these changes will be lost.

# %%
pst.write(os.path.join(template_ws, 'freyberg_mf6.pst'))
# Out:
# noptmax:0, npar_adj:25454, nnz_obs:920

# %% [markdown]
# So that was pretty epic. We now have a (very) high-dimensional PEST interface ready to roll.
#
# If you inspect the folder, you will see PEST control file and all the necessary instruction and template files. Because we have >10k parameters, version 2 of the PEST control file was written by default.
#
# Shall we check that it works? Let's run PEST once (i.e. with NOPTMAX=0). Now, by default, noptmax is set to zero. But just to check:

# %%
pst.control_data.noptmax
# Out:
# 0

# %% [markdown]
# OK, so if run PEST it will call the model once and then stop. (Hint: you can use any version of PEST++ to do this). If the next cell is sucessfull, then eveything is working. Check the folder, you should see PEST output files. (We will go into these and how to process PEST outcomes in subsequent tutorials).

# %%
pyemu.os_utils.run('pestpp-glm freyberg_mf6.pst', cwd=template_ws)

# %% [markdown]
# ### 8. Generate Prior Parameter Ensemble
#
# Before we go, let's take a look at our prior and sample from it to create a parameter ensemble. We will record the ensemble for future use.

# %%
# build the prior; you could also record this to an external file if desired, but it is pretty huge due to the number of parameters
cov = pf.build_prior(fmt='none')

# and take a peak at a slice of the matrix
x = cov.x.copy()
x[x==0] = np.NaN
plt.imshow(x[-49:,-49:])
# Out:
# 2022-02-18 11:09:24.941576 starting: building prior covariance matrix
# 2022-02-18 11:09:35.742895 finished: building prior covariance matrix took: 0:00:10.801319

# %%
pe = pf.draw(num_reals=100,use_specsim=True)
pe.enforce() # enforces parameter bounds
pe.to_binary(os.path.join(template_ws,"prior.jcb")) #writes the paramter ensemble to binary file

pst.pestpp_options["ies_parameter_ensemble"] = "prior.jcb" #adds pest++ options to the control file
pst.write(os.path.join(template_ws, 'freyberg_mf6.pst')) # rewrites thecontrol file with the new pest++ options
# Out:
# 2022-02-18 11:09:40.573898 starting: drawing realizations
# 2022-02-18 11:09:40.832207 starting: spectral simulation for grid-scale pars
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.126800 starting: SpecSim: drawing 100 realization for group npf_k_layer1_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.198912 finished: SpecSim: drawing 100 realization for group npf_k_layer1_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.072112
# 2022-02-18 11:09:41.202902 starting: SpecSim: drawing 100 realization for group npf_k_layer2_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.248779 finished: SpecSim: drawing 100 realization for group npf_k_layer2_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.045877
# 2022-02-18 11:09:41.252769 starting: SpecSim: drawing 100 realization for group npf_k_layer3_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.298646 finished: SpecSim: drawing 100 realization for group npf_k_layer3_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.045877
# 2022-02-18 11:09:41.302635 starting: SpecSim: drawing 100 realization for group npf_k33_layer1_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.352502 finished: SpecSim: drawing 100 realization for group npf_k33_layer1_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.049867
# 2022-02-18 11:09:41.357489 starting: SpecSim: drawing 100 realization for group npf_k33_layer2_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.402368 finished: SpecSim: drawing 100 realization for group npf_k33_layer2_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.044879
# 2022-02-18 11:09:41.407356 starting: SpecSim: drawing 100 realization for group npf_k33_layer3_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.452235 finished: SpecSim: drawing 100 realization for group npf_k33_layer3_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.044879
# 2022-02-18 11:09:41.457224 starting: SpecSim: drawing 100 realization for group sto_ss_layer2_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.502102 finished: SpecSim: drawing 100 realization for group sto_ss_layer2_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.044878
# 2022-02-18 11:09:41.507123 starting: SpecSim: drawing 100 realization for group sto_ss_layer3_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.554996 finished: SpecSim: drawing 100 realization for group sto_ss_layer3_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.047873
# 2022-02-18 11:09:41.558986 starting: SpecSim: drawing 100 realization for group sto_sy_layer1_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.604828 finished: SpecSim: drawing 100 realization for group sto_sy_layer1_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.045842
# 2022-02-18 11:09:41.608851 starting: SpecSim: drawing 100 realization for group rch_recharge_1_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.655691 finished: SpecSim: drawing 100 realization for group rch_recharge_1_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.046840
# 2022-02-18 11:09:41.658683 starting: SpecSim: drawing 100 realization for group rch_recharge_10_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.706609 finished: SpecSim: drawing 100 realization for group rch_recharge_10_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.047926
# 2022-02-18 11:09:41.710548 starting: SpecSim: drawing 100 realization for group rch_recharge_11_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.757472 finished: SpecSim: drawing 100 realization for group rch_recharge_11_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.046924
# 2022-02-18 11:09:41.762459 starting: SpecSim: drawing 100 realization for group rch_recharge_12_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.808336 finished: SpecSim: drawing 100 realization for group rch_recharge_12_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.045877
# 2022-02-18 11:09:41.812309 starting: SpecSim: drawing 100 realization for group rch_recharge_13_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.860197 finished: SpecSim: drawing 100 realization for group rch_recharge_13_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.047888
# 2022-02-18 11:09:41.864136 starting: SpecSim: drawing 100 realization for group rch_recharge_14_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.910012 finished: SpecSim: drawing 100 realization for group rch_recharge_14_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.045876
# 2022-02-18 11:09:41.914001 starting: SpecSim: drawing 100 realization for group rch_recharge_15_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:41.960877 finished: SpecSim: drawing 100 realization for group rch_recharge_15_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.046876
# 2022-02-18 11:09:41.964865 starting: SpecSim: drawing 100 realization for group rch_recharge_16_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.009745 finished: SpecSim: drawing 100 realization for group rch_recharge_16_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.044880
# 2022-02-18 11:09:42.013734 starting: SpecSim: drawing 100 realization for group rch_recharge_17_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.059612 finished: SpecSim: drawing 100 realization for group rch_recharge_17_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.045878
# 2022-02-18 11:09:42.062604 starting: SpecSim: drawing 100 realization for group rch_recharge_18_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.108481 finished: SpecSim: drawing 100 realization for group rch_recharge_18_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.045877
# 2022-02-18 11:09:42.112470 starting: SpecSim: drawing 100 realization for group rch_recharge_19_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.160343 finished: SpecSim: drawing 100 realization for group rch_recharge_19_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.047873
# 2022-02-18 11:09:42.163335 starting: SpecSim: drawing 100 realization for group rch_recharge_2_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.210209 finished: SpecSim: drawing 100 realization for group rch_recharge_2_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.046874
# 2022-02-18 11:09:42.214199 starting: SpecSim: drawing 100 realization for group rch_recharge_20_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.261073 finished: SpecSim: drawing 100 realization for group rch_recharge_20_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.046874
# 2022-02-18 11:09:42.265063 starting: SpecSim: drawing 100 realization for group rch_recharge_21_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.310939 finished: SpecSim: drawing 100 realization for group rch_recharge_21_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.045876
# 2022-02-18 11:09:42.315927 starting: SpecSim: drawing 100 realization for group rch_recharge_22_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.361804 finished: SpecSim: drawing 100 realization for group rch_recharge_22_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.045877
# 2022-02-18 11:09:42.365794 starting: SpecSim: drawing 100 realization for group rch_recharge_23_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.412668 finished: SpecSim: drawing 100 realization for group rch_recharge_23_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.046874
# 2022-02-18 11:09:42.416658 starting: SpecSim: drawing 100 realization for group rch_recharge_24_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.461575 finished: SpecSim: drawing 100 realization for group rch_recharge_24_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.044917
# 2022-02-18 11:09:42.466525 starting: SpecSim: drawing 100 realization for group rch_recharge_25_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.511404 finished: SpecSim: drawing 100 realization for group rch_recharge_25_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.044879
# 2022-02-18 11:09:42.516392 starting: SpecSim: drawing 100 realization for group rch_recharge_3_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.564263 finished: SpecSim: drawing 100 realization for group rch_recharge_3_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.047871
# 2022-02-18 11:09:42.569250 starting: SpecSim: drawing 100 realization for group rch_recharge_4_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.615128 finished: SpecSim: drawing 100 realization for group rch_recharge_4_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.045878
# 2022-02-18 11:09:42.620113 starting: SpecSim: drawing 100 realization for group rch_recharge_5_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.665990 finished: SpecSim: drawing 100 realization for group rch_recharge_5_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.045877
# 2022-02-18 11:09:42.669981 starting: SpecSim: drawing 100 realization for group rch_recharge_6_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.713864 finished: SpecSim: drawing 100 realization for group rch_recharge_6_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.043883
# 2022-02-18 11:09:42.717853 starting: SpecSim: drawing 100 realization for group rch_recharge_7_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.762785 finished: SpecSim: drawing 100 realization for group rch_recharge_7_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.044932
# 2022-02-18 11:09:42.766723 starting: SpecSim: drawing 100 realization for group rch_recharge_8_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.810638 finished: SpecSim: drawing 100 realization for group rch_recharge_8_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.043915
# 2022-02-18 11:09:42.814626 starting: SpecSim: drawing 100 realization for group rch_recharge_9_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334)
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:42.858477 finished: SpecSim: drawing 100 realization for group rch_recharge_9_gr with 706 pars, (log) variance 0.054284340773499334 (sill 0.054284340773499334) took: 0:00:00.043851
# SpecSim.initialize() summary: full_delx X full_dely: 72 X 72
# 2022-02-18 11:09:43.061086 finished: spectral simulation for grid-scale pars took: 0:00:02.228879
# 2022-02-18 11:09:43.062083 starting: Drawing non-specsim pars
# building diagonal cov
# processing  name:struct1,nugget:0.0,structures:
# name:var1,contribution:1.0,a:1000.0,anisotropy:1.0,bearing:0.0
#
# working on pargroups ['npf_k_layer1_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['npf_k_layer2_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['npf_k_layer3_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['npf_k33_layer1_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['npf_k33_layer2_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['npf_k33_layer3_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['sto_ss_layer2_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['sto_ss_layer3_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['sto_sy_layer1_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_1_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_10_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_11_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_12_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_13_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_14_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_15_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_16_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_17_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_18_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_19_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_2_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_20_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_21_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_22_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_23_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_24_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_25_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_3_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_4_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_5_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_6_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_7_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_8_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['rch_recharge_9_pp']
# build cov matrix
# done
# getting diag var cov 32
# scaling full cov by diag var cov
# working on pargroups ['ghbcond_gr']
# build cov matrix
# done
# getting diag var cov 10
# scaling full cov by diag var cov
# working on pargroups ['ghbcond_gr']
# build cov matrix
# done
# getting diag var cov 10
# scaling full cov by diag var cov
# working on pargroups ['ghbcond_gr']
# build cov matrix
# done
# getting diag var cov 10
# scaling full cov by diag var cov
# working on pargroups ['sfrcond_gr']
# build cov matrix
# done
# getting diag var cov 40
# scaling full cov by diag var cov
# processing  name:struct1,nugget:0.0,structures:
# name:var1,contribution:1.0,a:60.0,anisotropy:1.0,bearing:0.0
#
# working on pargroups ['wel_cst']
# build cov matrix
# done
# getting diag var cov 25
# scaling full cov by diag var cov
# working on pargroups ['sfr_gr']
# build cov matrix
# done
# getting diag var cov 25
# scaling full cov by diag var cov
# processing  name:struct1,nugget:0.0,structures:
# name:var1,contribution:1.0,a:1000.0,anisotropy:1.0,bearing:0.0
#
# working on pargroups ['ghbhead_gr']
# build cov matrix
# done
# getting diag var cov 10
# scaling full cov by diag var cov
# working on pargroups ['ghbhead_gr']
# build cov matrix
# done
# getting diag var cov 10
# scaling full cov by diag var cov
# working on pargroups ['ghbhead_gr']
# build cov matrix
# done
# getting diag var cov 10
# scaling full cov by diag var cov
# adding remaining parameters to diagonal
# 2022-02-18 11:09:49.988454 finished: Drawing non-specsim pars took: 0:00:06.926371
# 2022-02-18 11:09:52.042901 finished: drawing realizations took: 0:00:11.469003
# noptmax:0, npar_adj:25454, nnz_obs:920
